# %% [markdown]
# # Exercise 3 - GNNs Solutions
# ## Protein-Protein Interaction Prediction using Graph Neural Networks
#
# In this exercise, you will learn how to implement and apply Graph Neural Networks (GNNs) to predict [protein-protein interactions](https://en.wikipedia.org/wiki/Protein%E2%80%93protein_interaction) (PPIs). GNNs have shown great potential in various biological applications, including predicting protein functions, drug discovery, and more.
#
# Protein-protein interactions (PPIs) are essential to almost every process in a cell. Understanding PPIs is crucial for understanding cell physiology in normal and disease states. Furthermore, knowledge of PPIs can be used:
# * for drug development, since drugs can affect PPIs,
# * to assign roles (i.e., protein functions) to uncharacterized proteins,
# * to characterize the relationships between proteins that form multi-molecular complexes, such as the proteasome.
#
# We represent the totality of PPIs that happen in a cell, an organism or a specific biological context with a protein-protein interaction network. These networks are mathematical representations of all physical contacts between proteins in the cell.
#
# However, current knowledge of protein-protein interaction networks is both incomplete and noisy, as PPI screening techniques are limited in how many true interactions they can detect. Furthermore, PPI screening techniques often have high false positive and negative rates. These limitations present a great opportunity for computational methods to predict protein-protein interactions.
#
# Therefore, we are interested to take a protein-protein interaction network and use it to build a model for predicting new protein-protein interactions. We formulate this prediction task as a **link prediction problem** on unweighted and undirected networks and use a graph neural network to solve the task.
#
# We will use a sample protein-protein interaction network from [yeast *S. cerevisiae*](https://en.wikipedia.org/wiki/Saccharomyces_cerevisiae), in the form of an adjacency matrix and node feature matrix. Each node represents a protein, and the goal is to predict whether two proteins interact, i.e., is there an edge between the two nodes.

# %% [markdown]
# ## 1. Setup
# Let's import the necessary libraries. Note that this week, we'll implement the GNNs in pure [PyTorch](https://pytorch.org/docs/stable/index.html).

# %%
# %matplotlib inline

import time
import networkx as nx

import numpy as np
from scipy import sparse as sp
from matplotlib import pyplot as plt
from matplotlib.lines import Line2D
from sklearn.metrics import roc_auc_score, average_precision_score, roc_curve
import torch
from torch import nn
import torch.nn.functional as F

# %% [markdown]
# ## 2. Data
#
# ### 2.1. Downloading the data
# First, download the data from [here](https://snap.stanford.edu/deepnetbio-ismb/ipynb/yeast.edgelist) and copy it into a file called `yeast.edgelist`. This data contains the edges between the proteins.
# We then build a graph from this edge-list data, and extract the adjacency matrix.
#
# For this exercise, we will sample a subset of the graph to make it faster and easier.
#
# The entire dataset is represented as a single graph and our goal will be to train a GNN to predict new edges on this graph, representing potential new protein-protein interactions.

# %%
# Some utility functions
def load_data(filename='yeast.edgelist'):
    """Load the edgelist data and build a graph from it."""
    graph = nx.read_edgelist(filename)
    adjacency = nx.adjacency_matrix(graph)
    return graph, adjacency

def subsample_graph(graph, max_nodes=1000):
    """Sub-sample the graph to make it smaller."""
    graph = graph.subgraph(np.random.choice(graph.nodes(), max_nodes, replace=False)).copy()
    graph = graph.subgraph(sorted(nx.connected_components(graph), key=len, reverse=True)[0]).copy()  # keep only the largest connected component
    graph.remove_nodes_from(list(nx.isolates(graph)))
    adjacency = nx.adjacency_matrix(graph)
    return graph, adjacency

def get_edge_index(adjacency):
    """Return the indices of the edges in the graph."""
    # Edges are undirected here, so we consider only one half of the adjacency matrix
    adjacency = sp.triu(adjacency)
    return np.stack(adjacency.nonzero(), axis=0)

# %%
# Load the data and prepare a subgraph
graph, adjacency = load_data('yeast.edgelist')
graph, adjacency = subsample_graph(graph, max_nodes=1000)
edge_index = get_edge_index(adjacency)
print(graph)

N_NODES = adjacency.shape[0]
N_EDGES = edge_index.shape[1]
# Out:
# Graph with 926 nodes and 12681 edges

# %% [markdown]
# ### 2.2. Data splitting
#
# Now, let's split the data into training, validation, and test sets. To create the validation and test sets, we will select some existing edges to create positive examples and then sample some absent edges (by verifying they are not in the graph) to have negative examples.
#
# So, for each set, we:
# 1. sample X% of the edges as the positive examples,
# 2. create negative examples by selecting pairs of node that are not connected in the original graph, as many as we have positive edges.
#
# Finally, the train set will consist of the rest of the edges. In order to avoid training on the validation and test edges, we also build a mask for the adjacency matrix that will indicate if we supervise a given edge during training.

# %%
TEST_EDGE_RATIO = 0.05  # percent of edges to use for the validation and test set respectively

def split_graph_edges(adj, edge_index, test_edge_ratio=TEST_EDGE_RATIO):
    """Split the graph into train, valid and test edge sets."""
    # Get validation and test edges
    n_valid = n_test = int(N_EDGES * test_edge_ratio)
    valid_edges = edge_index[:, :n_valid]
    test_edges = edge_index[:, n_valid:n_valid + n_test]

    # Remove them from the training set
    train_edges = edge_index[:, n_valid + n_test:]

    # Sample "negative edges" for validation and test sets
    # As the adjacency matrix is sparse, we can sample them
    # randomly instead of enumerating all non-edges.
    neg_edge = []
    num_neg = n_valid + n_test
    while len(neg_edge) < num_neg:
        i, j = np.random.randint(0, N_NODES, size=(2,))
        if i != j and adj[i, j] == 0 and [i, j] not in neg_edge:
            neg_edge.append([i, j])
    valid_edges_neg = np.array(neg_edge[:n_valid]).T
    test_edges_neg = np.array(neg_edge[n_valid:]).T

    # Rebuild the training adjacency matrix
    adj_train = sp.csr_matrix((np.ones(train_edges.shape[1]), train_edges), shape=adj.shape)
    adj_train = adj_train + adj_train.T - sp.diags(adj_train.diagonal(), dtype=int)
    train_edges = get_edge_index(adj_train)
    
    # Build a training mask to avoid training on valid/test edges
    train_mask = np.ones(adj_train.shape, dtype=bool)
    for edges in [valid_edges, valid_edges_neg, test_edges, test_edges_neg]:
        train_mask[edges[0], edges[1]] = False
        train_mask[edges[1], edges[0]] = False  # also remove the reverse direction

    return adj_train, train_edges, train_mask, valid_edges, valid_edges_neg, test_edges, test_edges_neg

adj_train, train_edges, train_mask, valid_edges, valid_edges_neg, test_edges, test_edges_neg = split_graph_edges(adjacency, edge_index, TEST_EDGE_RATIO)
print(f"Edges split into:\n training: {train_edges.shape[1]}\n validation: {valid_edges.shape[1]}\n test: {test_edges.shape[1]}")

n_pos_edge = adj_train[train_mask].sum()
n_neg_edge = (1 - adj_train.todense())[train_mask].sum()
pos_weight = n_neg_edge / n_pos_edge  # weight of positive edges to compensate for the large imbalance
print(f"Ratio of negative/positive edges: {pos_weight:.2f}")
# Out:
# Edges split into:
#  training: 11413
#  validation: 634
#  test: 634
# Ratio of negative/positive edges: 36.75

# %% [markdown]
# Let's visualize (a part of) the graph data below. Note that we randomly sample nodes for this visualization, so it is possible we end up with more than a single connected component, even though the full graph has only one.

# %%
N = 200  # number of node to keep for the visualization

nodelist = np.random.permutation(graph.nodes())[:N]
subgraph = graph.subgraph(nodelist).copy()
subgraph.remove_edges_from(list(nx.selfloop_edges(subgraph)))  # remove self-loops for visualization
subgraph.remove_nodes_from(list(nx.isolates(subgraph)))  # remove isolated nodes for visualization
print(subgraph)

pos = nx.spring_layout(subgraph, iterations=100)

fig, ax = plt.subplots(1, 1)
ax.set_title('Sub-graph of the yeast protein-protein interaction network')
for edge_set, color in [(train_edges, 'C0'), (valid_edges, 'C1'), (test_edges, 'C2')]:
    edgelist = subgraph.edges(np.array(graph.nodes())[edge_set[0]])
    nx.draw_networkx(subgraph, pos, edgelist=edgelist, ax=ax, with_labels=False, node_size=5, node_color='black', edge_color=color, width=1., alpha=0.5)
ax.legend([Line2D([], [], color=c, linewidth=1., alpha=0.5) for c in ('C0', 'C1', 'C2')], ['train', 'validation', 'test']);
# Out:
# Graph with 166 nodes and 379 edges

# %% [markdown]
# ### 2.3. Preparing the data
#
# Now, we can prepare the data for PyTorch. The model takes as input the node embeddings and the adjacency matrix, and will predict edges.
#
# Note that this dataset does not have any node embeddings, the only available information are the existing interactions (the edges). So we will manually create embeddings for every node.

# %%
def sparse_array_to_tensor(adj):
    """Convert a scipy sparse matrix to a torch sparse tensor."""
    adj = adj.tocoo()
    return torch.sparse_coo_tensor(
        torch.LongTensor(np.vstack((adj.row, adj.col))), 
        torch.FloatTensor(adj.data),
        torch.Size(adj.shape)
    )

# Convert the data to PyTorch tensors
data = {
    'adj_train': sparse_array_to_tensor(adj_train).to_dense(),  # adjacency matrix of training set
    'train_edges': torch.LongTensor(train_edges),               # indices of edges in the training set
    'train_mask': torch.BoolTensor(train_mask),                 # boolean mask of edges in the training set
    'valid_edges': torch.LongTensor(valid_edges),               # indices of edges in the validation set
    'valid_edges_neg': torch.LongTensor(valid_edges_neg),       # indices of negative edges in the validation set
    'test_edges': torch.LongTensor(test_edges),                 # indices of edges in the test set
    'test_edges_neg': torch.LongTensor(test_edges_neg),         # indices of negative edges in the test set
}

# Embed the nodes as one-hot vectors
D_NODES = N_NODES  # number of dimensions
data['x_train'] = torch.eye(N_NODES)

# %% [markdown]
# ## 3. Graph Neural Networks
# Let's implement here a basic GNN using PyTorch.

# %% [markdown]
# ### 3.1. Graph Convolutional Layers
# Start by implementing layers to perform graph convolutions with simple neighborhood aggregation. They will be useful to build the Deep Graph Encoder part of the whole GNN model.
#
# <img src="img/neighb_agg.png" width="600" />
#
# As a reminder, the equation you saw in the course for such a layer is:
# $$
# \mathbf{h}_v^{(l+1)} = \sigma\left( \mathbf{W}_l \sum_{u\in N(v)} \frac{\mathbf{h}_u^{(l)}}{|N(v)|} + \mathbf{B}_l \mathbf{h}_v^{(l)} \right),
# $$
# where $v$ index the node, $l$ the layer, $\mathbf{h}$ are the node embeddings, $\sigma$ is a non-linearity, $N(v)$ is the set of neighbor of node $v$, and $\mathbf{W}$ and $\mathbf{B}$ are the trainable weight matrices of the layer. Or, in matrix form with the adjacency matrix (corrected by the inverse of the degree) $\tilde{A}$:
# $$
# H^{(l+1)} = \sigma\left( \tilde{A}H^{(l)}W_l^\top + H^{(l)}B_l^\top \right).
# $$
#
# **Note**: because of our naive data splitting and the sparsity of connections in the graph, some node may have no neighbors. For these nodes, be careful about the neighborhood aggregation as their degree is 0!

# %%
class GraphConv(nn.Module):
    """Basic graph convolutional layer implementing the simple neighborhood aggregation."""

    def __init__(self, in_features, out_features, activation=None):
        """
        Initialize the graph convolutional layer.
        
        Args:
            in_features (int): number of input node features.
            out_features (int): number of output node features.
            activation (nn.Module or callable): activation function to apply. (optional)
        """
        super().__init__()
        self.activation = activation

        # Learnable weight matrices, using linear layers
        self.weight = nn.Linear(in_features, out_features, bias=False)
        self.bias = nn.Linear(in_features, out_features, bias=False)

    def forward(self, x, adj):
        """
        Perform graph convolution operation.

        Args:
            x (Tensor): Input node features of shape (num_nodes, in_features).
            adj (Tensor): Adjacency matrix of the graph, shape (num_nodes, num_nodes).

        Returns:
            Tensor: Output node features after graph convolution, shape (num_nodes, out_features).
        """
        # Neighbourhood aggregation
        adj = adj / adj.sum(1, keepdim=True).clamp(min=1)
        x_agg = torch.matmul(adj, x)

        # Perform graph convolution
        x = self.weight(x_agg) + self.bias(x)

        # Apply activation function (e.g., ReLU)
        if self.activation is not None:
            x = self.activation(x)
        return x

# %% [markdown]
# Let's do a quick test to verify if it runs:

# %%
conv = GraphConv(D_NODES, 5, nn.ReLU())
out = conv(data['x_train'], data['adj_train'])

assert out.shape == (N_NODES, 5), f"Output shape should be (num_nodes, out_features), was {out.shape}"

# %% [markdown]
# ### 3.2. Prediction head
#
# In this exercise, we are interested in predicting potential new protein-protein interactions, meaning we want to do *edge prediction*.
#
# <img src="img/edge_pred.png" width="300" />
#
# In the lecture, you have seen two possibilities for the prediction heads at edge-level: (1) Concatenation + Linear or (2) Dot product.
#
# A potential problem with (1) is that it's not a symmetric operation, as $\mathrm{Concat}\left(\mathbf{h}_v, \mathbf{h}_u\right) \neq \mathrm{Concat}\left(\mathbf{h}_u, \mathbf{h}_v\right)$ in the general case. If  we have *directed* edges, this can be beneficial, but here the edges are undirected.
#
# In this exercise, as we want to do 1-way prediction (is there an edge or not) we only ask you to implement (2):
# * `DotProductHead`: dot product between the node embeddings, and we add a linear transformation on the results: $\hat{\mathbf{y}}_{uv} = w\left( \mathbf{h}_v ^\top \mathbf{h}_u\right) + b$, where $w$ and $b$ are both trainable parameters.
#
# **Remark**: to get a probability for each edge, we could use the sigmoid function on the final results: $\mathrm{sigmoid}(\hat{\mathbf{y}}_{uv})$. However, here we will not directly include it in the model. The reason is that during training, we'll then be able to use [`torch.nn.BCEWithLogitsLoss`](https://pytorch.org/docs/stable/generated/torch.nn.BCEWithLogitsLoss.html?highlight=bcewithlogits#torch.nn.BCEWithLogitsLoss) instead of [`torch.nn.BCELoss`](https://pytorch.org/docs/stable/generated/torch.nn.BCELoss.html?highlight=bce#torch.nn.BCELoss), which is more stable numerically.
# Then, when using the model for prediction, we will manually apply the sigmoid on its output to get probabilities.

# %%
class DotProductHead(nn.Module):
    """Prediction head using dot product between node embeddings for edge prediction."""

    def __init__(self):
        """Initialize the prediction head."""
        super().__init__()
        self.linear = nn.Linear(1, 1)

    def forward(self, x):
        """
        Edge-level prediction given the node embeddings.

        Args:
            x (Tensor): Input node features of shape (num_nodes, in_features).

        Returns:
            Tensor: Edge predictions of shape (num_nodes, num_nodes).
        """
        x = (x @ x.transpose(0, 1))
        return self.linear(x.unsqueeze(-1)).squeeze(-1)

# %%
# Let's do a quick test as well.
head = DotProductHead()
out = head(data['x_train'])

assert out.shape == (N_NODES, N_NODES), f"Output shape should be (num_nodes, num_nodes), was {out.shape}"

# %% [markdown]
# ### 3.3. GNN full model
# Implement the entire GNN model, which consists in an initial Deep Graph Encoder part, to obtain node embeddings, followed by a prediction head.
#
# <img src="img/gnn_net.png" width="700" />
#
# **Important**: as our prediction head is a simple dot product, it might be better to avoid having an activation function on the previous layer. Indeed, for example, a ReLU would prevent any negative values, so that all the dot product would be strictly positive!

# %%
class GNN(nn.Module):
    """A full Graph Neural Network for edge prediction."""

    def __init__(self, num_features, conv_dims, activation, dropout=0.):
        """
        Initialize the GNN model for edge prediction.

        Args:
            num_features (int): Number of input node features.
            conv_dims (list of int): Number of hidden features in each graph convolution layers.
            activation (nn.Module or callable): Activation function to apply.
            dropout (float): Dropout probability. (optional)
        """
        super().__init__()
        self.activation = activation
        self.dropout = dropout

        # Deep Graph Encoder layers
        self.conv_layers = nn.ModuleList()
        self.conv_layers.append(GraphConv(num_features, conv_dims[0], activation))
        for i in range(len(conv_dims) - 2):
            self.conv_layers.append(GraphConv(conv_dims[i], conv_dims[i+1], activation))
        self.conv_layers.append(GraphConv(conv_dims[-2], conv_dims[-1], None))

        # We add Batch normalization layers to help with training
        self.norms = nn.ModuleList()
        for dim in conv_dims:
            self.norms.append(nn.BatchNorm1d(dim))

        # Prediction head
        self.head = DotProductHead()

    def forward(self, x, adj):
        """
        Perform forward pass for edge prediction.

        Args:
            x (Tensor): Input node features of shape (num_nodes, num_features).
            adj (Tensor): Adjacency matrix of the graph, shape (num_nodes, num_nodes).

        Returns:
            Tensor: Predicted edge probabilities for each pair of nodes, shape (num_nodes, num_nodes).
        """
        # Apply multiple graph convolution layers
        for layer, norm in zip(self.conv_layers, self.norms):
            x = layer(x, adj)
            x = norm(x)
            x = F.dropout(x, p=self.dropout, training=self.training)

        # Predict edges presence
        x = self.head(x)

        return x

# %% [markdown]
# Again, let's quickly verify that our model runs:

# %%
model = GNN(num_features=D_NODES, conv_dims=[5, 5], activation=nn.ReLU())
out = model(data['x_train'], data['adj_train'])

assert out.shape == (N_NODES, N_NODES), f"Output shape should be (num_nodes, num_nodes), was {out.shape}"

# %% [markdown]
# ## 4. Training

# %% [markdown]
# ### 4.1. Utilities
# Define functions to implement a *single training step*, compute train and test metrics, and visualize the Receiver Operating Characteristic Curbe (ROC curve), see [here](https://scikit-learn.org/stable/modules/generated/sklearn.metrics.roc_curve.html).
#
# For the metrics, we use scikit-learn to compute the following:
# 1. `roc_auc_score`: Area Under the Receiver Operating Characteristic Curve (ROC AUC), see [here](https://scikit-learn.org/stable/modules/generated/sklearn.metrics.roc_auc_score.html).
# 2. `average_precision_score`: Average Precision (AP), see [here](https://scikit-learn.org/stable/modules/generated/sklearn.metrics.average_precision_score.html).

# %%
def train_step(data, model, loss_fn, optimizer):
    """
    Train the model for one step on the network data.

    Hint: do not forget to mask the loss!
    
    Args:
        data (dict): Dictionary of tensors containing the data.
        model (nn.Module): Model to be trained.
        loss_fn (nn.Module): Loss function to be optimized.
        optimizer (torch.optim.Optimizer): Optimizer to use for training.

    Returns:
        float: Loss value.
    """
    # Set model to train mode
    model.train()

    # Compute prediction and loss
    pred = model(data['x_train'], data['adj_train'])
    loss = loss_fn(pred[data['train_mask']], 
                   data['adj_train'][data['train_mask']])

    # 1. Set the gradient of trainable parameters to 0.
    optimizer.zero_grad()
    # 2. Automatically calculate the gradient of trainable parameters.
    loss.backward()
    # 3. Automatically update the trainable parameters using the gradient.
    optimizer.step()

    # Return the loss
    return loss.item()


@torch.no_grad()  # decorator to deactivate autograd functionality in this function
def get_train_accuracy(data, model, threshold=0.5):
    """
    Compute accuracy of the edge prediction on the training data.

    Hint: do not forget to mask the train edges.

    Args:
        data (dict): Dictionary of tensors containing the data.
        model (nn.Module): Model to be tested.

    Returns:
        tuple(float, float): Accuracy for positive edges, accuracy for negative edges (in %).
    """
    # Set the model to evaluation mode
    model.eval()

    # Predictions (binary)
    pred = model(data['x_train'], data['adj_train'])
    pred = torch.sigmoid(pred) >= threshold

    # Compute the accuracy for positive and negative edges
    acc_pos = pred[data['adj_train'].bool() & data['train_mask']].sum().item() / n_pos_edge * 100
    acc_neg = (~pred)[~data['adj_train'].bool() & data['train_mask']].sum().item() / n_neg_edge * 100

    return acc_pos, acc_neg


@torch.no_grad()
def test(data, model, edges_pos, edges_neg):
    """
    Test the model's prediction on the positive and negative edges.

    Args:
        data (dict): Dictionary of tensors containing the data.
        model (nn.Module): Model to be tested.
        edges_pos (Tensor): Positive edges to be predicted.
        edges_neg (Tensor): Negative edges to be predicted.

    Returns:
        tuple(float, float): Area under ROC curve, and average precision metrics.
    """
    # Set the model to evaluation mode
    model.eval()

    # Predictions
    pred = model(data['x_train'], data['adj_train'])
    pred = torch.sigmoid(pred)

    # Select the predictions corresponding to the positive and negative edges
    pred_pos = pred[edges_pos[0], edges_pos[1]]
    pred_neg = pred[edges_neg[0], edges_neg[1]]

    # Stack the predictions and true values
    pred_all = torch.cat([pred_neg, pred_pos])
    labels_all = torch.cat([torch.zeros_like(pred_neg), torch.ones_like(pred_pos)])

    # Compute the metrics
    roc_score = roc_auc_score(labels_all, pred_all)
    ap_score = average_precision_score(labels_all, pred_all)
    return roc_score, ap_score


@torch.no_grad()
def plot_roc_curve(data, model, edges_pos, edges_neg):
    """
    Plot the ROC curve given the positive and negative edges.

    Args:
        data (dict): Dictionary of tensors containing the data.
        model (nn.Module): Model to be tested.
        edges_pos (Tensor): Positive edges to be predicted.
        edges_neg (Tensor): Negative edges to be predicted.

    Returns:
        matplotlib.figure.Figure: The ROC curve figure.
    """
    # Set the model to evaluation mode
    model.eval()

    # Predictions
    pred = model(data['x_train'], data['adj_train'])
    pred = torch.sigmoid(pred)

    # Select the predictions corresponding to the positive and negative edges
    pred_pos = pred[edges_pos[0], edges_pos[1]]
    pred_neg = pred[edges_neg[0], edges_neg[1]]

    # Stack the predictions and true values
    pred_all = torch.cat([pred_neg, pred_pos])
    labels_all = torch.cat([torch.zeros_like(pred_neg), torch.ones_like(pred_pos)])

    # Compute the false positive rate and true positive rate
    fpr, tpr, _ = roc_curve(labels_all, pred_all)

    # Plot the ROC curve
    fig, ax = plt.subplots(1, 1)
    ax.plot(fpr, tpr, label='ROC curve\n(with threshold values)')
    ax.set_xlim(0., 1.)
    ax.set_ylim(0., 1.)
    ax.set_xlabel('False positive rate')
    ax.set_ylabel('True positive rate')
    ax.set_title('ROC curve')
    ax.grid()
    return fig

# %% [markdown]
# ### 4.2. Complete training
# We will now combine everything to train and evaluate our model.
#
# The main steps are:
# 1. Prepare and preprocess the data (already done above)
# 2. Define the model
# 3. Define the training loss and optimizer
# 4. Train the model

# %%
# Hyper-parameters (feel free to change these)
learning_rate = 1e-3
epochs = 400
conv_dims = [512, 256]
activation = nn.LeakyReLU()
dropout = 0.1

# 1. Data
# We already loaded and prepared the data above

# 2. Model
model = GNN(num_features=D_NODES, conv_dims=conv_dims, activation=activation, dropout=dropout)
#print(model)

# 3. Initialize the loss function and optimizer
# We weight the samples to compensate for the class imbalance (there are very few edges compared to non-edges)
loss_fn = nn.BCEWithLogitsLoss(pos_weight=torch.tensor(pos_weight))
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)

history = {"epoch": 0, "loss": [], "acc-pos": [], "acc-neg": [], "val-roc": [], "val-ap": []}

# %%
# 4. Main training loop
def train_loop(history, data, model, loss_fn, optimizer, epochs):
    """Full training loop over the dataset for several epochs."""
    for t in range(epochs):
        start_epoch = time.time()  # time the epoch
        print(f"Epoch {t+1: 3d}/{epochs}:", end="")

        # Training step
        train_loss = train_step(data, model, loss_fn, optimizer)
        print(f" loss: {train_loss:.4f}", end="")

        # Trainin accuracy
        acc_pos, acc_neg = get_train_accuracy(data, model, threshold=0.5)
        print(f" - acc-pos: {acc_pos:.1f}% - acc-neg: {acc_neg:.1f}%", end="")

        # Validation
        valid_roc, valid_ap = test(data, model, data['valid_edges'], data['valid_edges_neg'])
        print(f" - val-roc: {valid_roc:.4f} - val-ap: {valid_ap:.4f}", end="")
            
        # Log
        history['epoch'] += 1
        history['loss'].append(train_loss)
        history['acc-pos'].append(acc_pos)
        history['acc-neg'].append(acc_neg)
        history['val-roc'].append(valid_roc)
        history['val-ap'].append(valid_ap)
        print(f" ({time.time() - start_epoch:.1f}s/epoch)")
    print("Done!")
    return history

history = train_loop(history, data, model, loss_fn, optimizer, epochs)

fig, axs = plt.subplots(1, 4,  figsize=(16, 4))
axs[0].plot(history['loss'])
axs[0].set_title('Training loss')
axs[1].plot(history['acc-pos'], label='positive edges')
axs[1].plot(history['acc-neg'], label='negative edges')
axs[1].set_title('Training accuracy')
axs[1].legend()
axs[2].plot(history['val-roc'])
axs[2].set_title('Validation ROC-AUC')
axs[3].plot(history['val-ap'])
axs[3].set_title('Validation Average Precision');
# Out:
# Epoch   1/400: loss: 1.2534 - acc-pos: 100.0% - acc-neg: 18.8% - val-roc: 0.4390 - val-ap: 0.4435 (0.1s/epoch)
# Epoch   2/400: loss: 1.2463 - acc-pos: 100.0% - acc-neg: 18.8% - val-roc: 0.4375 - val-ap: 0.4429 (0.1s/epoch)
# Epoch   3/400: loss: 1.2496 - acc-pos: 100.0% - acc-neg: 18.8% - val-roc: 0.4383 - val-ap: 0.4433 (0.1s/epoch)
# Epoch   4/400: loss: 1.2516 - acc-pos: 100.0% - acc-neg: 19.1% - val-roc: 0.4417 - val-ap: 0.4449 (0.1s/epoch)
# Epoch   5/400: loss: 1.2410 - acc-pos: 100.0% - acc-neg: 19.2% - val-roc: 0.4486 - val-ap: 0.4485 (0.1s/epoch)
# Epoch   6/400: loss: 1.2410 - acc-pos: 100.0% - acc-neg: 19.4% - val-roc: 0.4546 - val-ap: 0.4517 (0.1s/epoch)
# Epoch   7/400: loss: 1.2346 - acc-pos: 100.0% - acc-neg: 19.5% - val-roc: 0.4585 - val-ap: 0.4540 (0.1s/epoch)
# Epoch   8/400: loss: 1.2432 - acc-pos: 100.0% - acc-neg: 19.6% - val-roc: 0.4597 - val-ap: 0.4551 (0.1s/epoch)
# Epoch   9/400: loss: 1.2433 - acc-pos: 100.0% - acc-neg: 19.2% - val-roc: 0.4600 - val-ap: 0.4553 (0.1s/epoch)
# Epoch  10/400: loss: 1.2382 - acc-pos: 100.0% - acc-neg: 18.7% - val-roc: 0.4567 - val-ap: 0.4540 (0.1s/epoch)
# Epoch  11/400: loss: 1.2274 - acc-pos: 100.0% - acc-neg: 18.3% - val-roc: 0.4525 - val-ap: 0.4516 (0.1s/epoch)
# Epoch  12/400: loss: 1.2303 - acc-pos: 100.0% - acc-neg: 18.1% - val-roc: 0.4473 - val-ap: 0.4482 (0.1s/epoch)
# Epoch  13/400: loss: 1.2258 - acc-pos: 100.0% - acc-neg: 18.1% - val-roc: 0.4405 - val-ap: 0.4441 (0.1s/epoch)
# Epoch  14/400: loss: 1.2346 - acc-pos: 100.0% - acc-neg: 18.5% - val-roc: 0.4397 - val-ap: 0.4434 (0.1s/epoch)
# Epoch  15/400: loss: 1.2347 - acc-pos: 100.0% - acc-neg: 18.9% - val-roc: 0.4413 - val-ap: 0.4442 (0.1s/epoch)
# Epoch  16/400: loss: 1.2183 - acc-pos: 100.0% - acc-neg: 19.2% - val-roc: 0.4432 - val-ap: 0.4452 (0.1s/epoch)
# Epoch  17/400: loss: 1.2213 - acc-pos: 100.0% - acc-neg: 19.4% - val-roc: 0.4463 - val-ap: 0.4470 (0.1s/epoch)
# Epoch  18/400: loss: 1.2246 - acc-pos: 100.0% - acc-neg: 19.6% - val-roc: 0.4476 - val-ap: 0.4478 (0.1s/epoch)
# Epoch  19/400: loss: 1.2179 - acc-pos: 100.0% - acc-neg: 20.0% - val-roc: 0.4511 - val-ap: 0.4498 (0.1s/epoch)
# Epoch  20/400: loss: 1.2196 - acc-pos: 100.0% - acc-neg: 20.0% - val-roc: 0.4511 - val-ap: 0.4498 (0.1s/epoch)
# Epoch  21/400: loss: 1.2155 - acc-pos: 100.0% - acc-neg: 19.7% - val-roc: 0.4500 - val-ap: 0.4492 (0.1s/epoch)
# Epoch  22/400: loss: 1.2251 - acc-pos: 100.0% - acc-neg: 19.2% - val-roc: 0.4442 - val-ap: 0.4464 (0.1s/epoch)
# Epoch  23/400: loss: 1.2201 - acc-pos: 100.0% - acc-neg: 19.1% - val-roc: 0.4399 - val-ap: 0.4443 (0.1s/epoch)
# Epoch  24/400: loss: 1.2033 - acc-pos: 100.0% - acc-neg: 18.8% - val-roc: 0.4357 - val-ap: 0.4424 (0.1s/epoch)
# Epoch  25/400: loss: 1.2130 - acc-pos: 100.0% - acc-neg: 18.7% - val-roc: 0.4318 - val-ap: 0.4405 (0.1s/epoch)
# Epoch  26/400: loss: 1.2111 - acc-pos: 100.0% - acc-neg: 18.8% - val-roc: 0.4315 - val-ap: 0.4404 (0.1s/epoch)
# Epoch  27/400: loss: 1.2154 - acc-pos: 100.0% - acc-neg: 18.8% - val-roc: 0.4346 - val-ap: 0.4423 (0.1s/epoch)
# Epoch  28/400: loss: 1.2055 - acc-pos: 100.0% - acc-neg: 19.1% - val-roc: 0.4409 - val-ap: 0.4457 (0.1s/epoch)
# Epoch  29/400: loss: 1.1997 - acc-pos: 100.0% - acc-neg: 19.4% - val-roc: 0.4465 - val-ap: 0.4488 (0.1s/epoch)
# Epoch  30/400: loss: 1.1972 - acc-pos: 100.0% - acc-neg: 19.8% - val-roc: 0.4509 - val-ap: 0.4513 (0.1s/epoch)
# Epoch  31/400: loss: 1.2016 - acc-pos: 100.0% - acc-neg: 19.8% - val-roc: 0.4522 - val-ap: 0.4521 (0.1s/epoch)
# Epoch  32/400: loss: 1.2081 - acc-pos: 100.0% - acc-neg: 19.9% - val-roc: 0.4520 - val-ap: 0.4523 (0.1s/epoch)
# Epoch  33/400: loss: 1.2024 - acc-pos: 100.0% - acc-neg: 20.0% - val-roc: 0.4512 - val-ap: 0.4520 (0.1s/epoch)
# Epoch  34/400: loss: 1.1948 - acc-pos: 100.0% - acc-neg: 20.1% - val-roc: 0.4480 - val-ap: 0.4509 (0.1s/epoch)
# Epoch  35/400: loss: 1.1917 - acc-pos: 100.0% - acc-neg: 20.2% - val-roc: 0.4464 - val-ap: 0.4502 (0.1s/epoch)
# Epoch  36/400: loss: 1.1962 - acc-pos: 100.0% - acc-neg: 20.5% - val-roc: 0.4476 - val-ap: 0.4510 (0.1s/epoch)
# Epoch  37/400: loss: 1.1955 - acc-pos: 100.0% - acc-neg: 20.5% - val-roc: 0.4489 - val-ap: 0.4518 (0.1s/epoch)
# Epoch  38/400: loss: 1.1869 - acc-pos: 100.0% - acc-neg: 20.5% - val-roc: 0.4521 - val-ap: 0.4536 (0.1s/epoch)
# Epoch  39/400: loss: 1.1899 - acc-pos: 100.0% - acc-neg: 20.6% - val-roc: 0.4526 - val-ap: 0.4541 (0.1s/epoch)
# Epoch  40/400: loss: 1.1875 - acc-pos: 100.0% - acc-neg: 20.8% - val-roc: 0.4523 - val-ap: 0.4540 (0.1s/epoch)
# Epoch  41/400: loss: 1.1909 - acc-pos: 100.0% - acc-neg: 20.9% - val-roc: 0.4533 - val-ap: 0.4545 (0.1s/epoch)
# Epoch  42/400: loss: 1.1879 - acc-pos: 100.0% - acc-neg: 20.9% - val-roc: 0.4537 - val-ap: 0.4550 (0.1s/epoch)
# Epoch  43/400: loss: 1.1822 - acc-pos: 100.0% - acc-neg: 20.9% - val-roc: 0.4528 - val-ap: 0.4545 (0.1s/epoch)
# Epoch  44/400: loss: 1.1770 - acc-pos: 100.0% - acc-neg: 20.7% - val-roc: 0.4529 - val-ap: 0.4548 (0.1s/epoch)
# Epoch  45/400: loss: 1.1787 - acc-pos: 100.0% - acc-neg: 20.4% - val-roc: 0.4506 - val-ap: 0.4536 (0.1s/epoch)
# Epoch  46/400: loss: 1.1776 - acc-pos: 100.0% - acc-neg: 20.2% - val-roc: 0.4473 - val-ap: 0.4519 (0.1s/epoch)
# Epoch  47/400: loss: 1.1774 - acc-pos: 100.0% - acc-neg: 20.1% - val-roc: 0.4450 - val-ap: 0.4505 (0.1s/epoch)
# Epoch  48/400: loss: 1.1780 - acc-pos: 100.0% - acc-neg: 20.3% - val-roc: 0.4468 - val-ap: 0.4511 (0.1s/epoch)
# Epoch  49/400: loss: 1.1703 - acc-pos: 100.0% - acc-neg: 20.7% - val-roc: 0.4511 - val-ap: 0.4532 (0.1s/epoch)
# Epoch  50/400: loss: 1.1725 - acc-pos: 100.0% - acc-neg: 21.2% - val-roc: 0.4542 - val-ap: 0.4548 (0.1s/epoch)
# Epoch  51/400: loss: 1.1725 - acc-pos: 100.0% - acc-neg: 21.3% - val-roc: 0.4586 - val-ap: 0.4568 (0.1s/epoch)
# Epoch  52/400: loss: 1.1733 - acc-pos: 100.0% - acc-neg: 21.5% - val-roc: 0.4609 - val-ap: 0.4576 (0.1s/epoch)
# Epoch  53/400: loss: 1.1772 - acc-pos: 100.0% - acc-neg: 21.3% - val-roc: 0.4606 - val-ap: 0.4572 (0.1s/epoch)
# Epoch  54/400: loss: 1.1682 - acc-pos: 100.0% - acc-neg: 21.2% - val-roc: 0.4601 - val-ap: 0.4568 (0.1s/epoch)
# Epoch  55/400: loss: 1.1643 - acc-pos: 100.0% - acc-neg: 21.0% - val-roc: 0.4591 - val-ap: 0.4561 (0.1s/epoch)
# Epoch  56/400: loss: 1.1615 - acc-pos: 100.0% - acc-neg: 20.8% - val-roc: 0.4573 - val-ap: 0.4556 (0.1s/epoch)
# Epoch  57/400: loss: 1.1702 - acc-pos: 100.0% - acc-neg: 20.7% - val-roc: 0.4571 - val-ap: 0.4560 (0.1s/epoch)
# Epoch  58/400: loss: 1.1633 - acc-pos: 100.0% - acc-neg: 20.6% - val-roc: 0.4569 - val-ap: 0.4557 (0.1s/epoch)
# Epoch  59/400: loss: 1.1617 - acc-pos: 100.0% - acc-neg: 20.7% - val-roc: 0.4549 - val-ap: 0.4548 (0.1s/epoch)
# Epoch  60/400: loss: 1.1600 - acc-pos: 100.0% - acc-neg: 20.7% - val-roc: 0.4532 - val-ap: 0.4541 (0.1s/epoch)
# Epoch  61/400: loss: 1.1577 - acc-pos: 100.0% - acc-neg: 20.7% - val-roc: 0.4524 - val-ap: 0.4536 (0.1s/epoch)
# Epoch  62/400: loss: 1.1592 - acc-pos: 100.0% - acc-neg: 21.1% - val-roc: 0.4554 - val-ap: 0.4552 (0.1s/epoch)
# Epoch  63/400: loss: 1.1537 - acc-pos: 100.0% - acc-neg: 21.3% - val-roc: 0.4552 - val-ap: 0.4554 (0.1s/epoch)
# Epoch  64/400: loss: 1.1589 - acc-pos: 100.0% - acc-neg: 21.4% - val-roc: 0.4553 - val-ap: 0.4554 (0.1s/epoch)
# Epoch  65/400: loss: 1.1466 - acc-pos: 100.0% - acc-neg: 21.5% - val-roc: 0.4548 - val-ap: 0.4552 (0.1s/epoch)
# Epoch  66/400: loss: 1.1526 - acc-pos: 100.0% - acc-neg: 21.4% - val-roc: 0.4529 - val-ap: 0.4544 (0.1s/epoch)
# Epoch  67/400: loss: 1.1521 - acc-pos: 100.0% - acc-neg: 21.3% - val-roc: 0.4507 - val-ap: 0.4533 (0.1s/epoch)
# Epoch  68/400: loss: 1.1507 - acc-pos: 100.0% - acc-neg: 21.3% - val-roc: 0.4495 - val-ap: 0.4530 (0.1s/epoch)
# Epoch  69/400: loss: 1.1453 - acc-pos: 100.0% - acc-neg: 21.2% - val-roc: 0.4472 - val-ap: 0.4520 (0.1s/epoch)
# Epoch  70/400: loss: 1.1476 - acc-pos: 100.0% - acc-neg: 21.3% - val-roc: 0.4490 - val-ap: 0.4535 (0.1s/epoch)
# Epoch  71/400: loss: 1.1486 - acc-pos: 100.0% - acc-neg: 21.3% - val-roc: 0.4518 - val-ap: 0.4556 (0.1s/epoch)
# Epoch  72/400: loss: 1.1457 - acc-pos: 100.0% - acc-neg: 21.3% - val-roc: 0.4528 - val-ap: 0.4563 (0.1s/epoch)
# Epoch  73/400: loss: 1.1409 - acc-pos: 100.0% - acc-neg: 21.5% - val-roc: 0.4548 - val-ap: 0.4578 (0.1s/epoch)
# Epoch  74/400: loss: 1.1371 - acc-pos: 100.0% - acc-neg: 21.6% - val-roc: 0.4554 - val-ap: 0.4586 (0.1s/epoch)
# Epoch  75/400: loss: 1.1381 - acc-pos: 100.0% - acc-neg: 21.5% - val-roc: 0.4555 - val-ap: 0.4589 (0.1s/epoch)
# Epoch  76/400: loss: 1.1363 - acc-pos: 100.0% - acc-neg: 21.5% - val-roc: 0.4560 - val-ap: 0.4589 (0.1s/epoch)
# Epoch  77/400: loss: 1.1359 - acc-pos: 100.0% - acc-neg: 21.5% - val-roc: 0.4553 - val-ap: 0.4583 (0.1s/epoch)
# Epoch  78/400: loss: 1.1364 - acc-pos: 100.0% - acc-neg: 21.5% - val-roc: 0.4556 - val-ap: 0.4584 (0.1s/epoch)
# Epoch  79/400: loss: 1.1365 - acc-pos: 100.0% - acc-neg: 21.6% - val-roc: 0.4534 - val-ap: 0.4573 (0.1s/epoch)
# Epoch  80/400: loss: 1.1363 - acc-pos: 100.0% - acc-neg: 21.8% - val-roc: 0.4519 - val-ap: 0.4564 (0.1s/epoch)
# Epoch  81/400: loss: 1.1399 - acc-pos: 100.0% - acc-neg: 21.9% - val-roc: 0.4490 - val-ap: 0.4545 (0.1s/epoch)
# Epoch  82/400: loss: 1.1338 - acc-pos: 100.0% - acc-neg: 21.8% - val-roc: 0.4473 - val-ap: 0.4536 (0.1s/epoch)
# Epoch  83/400: loss: 1.1356 - acc-pos: 100.0% - acc-neg: 21.9% - val-roc: 0.4477 - val-ap: 0.4538 (0.1s/epoch)
# Epoch  84/400: loss: 1.1245 - acc-pos: 100.0% - acc-neg: 22.0% - val-roc: 0.4498 - val-ap: 0.4549 (0.1s/epoch)
# Epoch  85/400: loss: 1.1254 - acc-pos: 100.0% - acc-neg: 21.9% - val-roc: 0.4487 - val-ap: 0.4544 (0.1s/epoch)
# Epoch  86/400: loss: 1.1243 - acc-pos: 100.0% - acc-neg: 21.9% - val-roc: 0.4479 - val-ap: 0.4545 (0.1s/epoch)
# Epoch  87/400: loss: 1.1223 - acc-pos: 100.0% - acc-neg: 21.9% - val-roc: 0.4472 - val-ap: 0.4542 (0.1s/epoch)
# Epoch  88/400: loss: 1.1236 - acc-pos: 100.0% - acc-neg: 22.0% - val-roc: 0.4484 - val-ap: 0.4548 (0.1s/epoch)
# Epoch  89/400: loss: 1.1234 - acc-pos: 100.0% - acc-neg: 22.2% - val-roc: 0.4521 - val-ap: 0.4567 (0.1s/epoch)
# Epoch  90/400: loss: 1.1184 - acc-pos: 100.0% - acc-neg: 22.2% - val-roc: 0.4535 - val-ap: 0.4574 (0.1s/epoch)
# Epoch  91/400: loss: 1.1204 - acc-pos: 100.0% - acc-neg: 22.4% - val-roc: 0.4558 - val-ap: 0.4585 (0.1s/epoch)
# Epoch  92/400: loss: 1.1271 - acc-pos: 100.0% - acc-neg: 22.5% - val-roc: 0.4581 - val-ap: 0.4598 (0.1s/epoch)
# Epoch  93/400: loss: 1.1205 - acc-pos: 100.0% - acc-neg: 22.6% - val-roc: 0.4615 - val-ap: 0.4619 (0.1s/epoch)
# Epoch  94/400: loss: 1.1191 - acc-pos: 100.0% - acc-neg: 22.6% - val-roc: 0.4642 - val-ap: 0.4636 (0.1s/epoch)
# Epoch  95/400: loss: 1.1185 - acc-pos: 100.0% - acc-neg: 22.7% - val-roc: 0.4655 - val-ap: 0.4642 (0.1s/epoch)
# Epoch  96/400: loss: 1.1193 - acc-pos: 100.0% - acc-neg: 22.6% - val-roc: 0.4660 - val-ap: 0.4646 (0.1s/epoch)
# Epoch  97/400: loss: 1.1147 - acc-pos: 100.0% - acc-neg: 22.5% - val-roc: 0.4645 - val-ap: 0.4637 (0.1s/epoch)
# Epoch  98/400: loss: 1.1180 - acc-pos: 100.0% - acc-neg: 22.4% - val-roc: 0.4619 - val-ap: 0.4622 (0.1s/epoch)
# Epoch  99/400: loss: 1.1167 - acc-pos: 100.0% - acc-neg: 22.6% - val-roc: 0.4599 - val-ap: 0.4612 (0.1s/epoch)
# Epoch  100/400: loss: 1.1107 - acc-pos: 100.0% - acc-neg: 22.8% - val-roc: 0.4584 - val-ap: 0.4610 (0.1s/epoch)
# Epoch  101/400: loss: 1.1098 - acc-pos: 100.0% - acc-neg: 22.8% - val-roc: 0.4559 - val-ap: 0.4603 (0.1s/epoch)
# Epoch  102/400: loss: 1.1084 - acc-pos: 100.0% - acc-neg: 22.7% - val-roc: 0.4536 - val-ap: 0.4593 (0.1s/epoch)
# Epoch  103/400: loss: 1.1113 - acc-pos: 100.0% - acc-neg: 22.8% - val-roc: 0.4515 - val-ap: 0.4587 (0.1s/epoch)
# Epoch  104/400: loss: 1.1087 - acc-pos: 100.0% - acc-neg: 23.1% - val-roc: 0.4529 - val-ap: 0.4592 (0.1s/epoch)
# Epoch  105/400: loss: 1.1099 - acc-pos: 100.0% - acc-neg: 23.5% - val-roc: 0.4574 - val-ap: 0.4613 (0.1s/epoch)
# Epoch  106/400: loss: 1.1014 - acc-pos: 100.0% - acc-neg: 23.6% - val-roc: 0.4607 - val-ap: 0.4627 (0.1s/epoch)
# Epoch  107/400: loss: 1.1134 - acc-pos: 100.0% - acc-neg: 24.0% - val-roc: 0.4637 - val-ap: 0.4640 (0.1s/epoch)
# Epoch  108/400: loss: 1.1059 - acc-pos: 100.0% - acc-neg: 24.3% - val-roc: 0.4661 - val-ap: 0.4649 (0.1s/epoch)
# Epoch  109/400: loss: 1.1122 - acc-pos: 100.0% - acc-neg: 24.6% - val-roc: 0.4673 - val-ap: 0.4654 (0.1s/epoch)
# Epoch  110/400: loss: 1.1073 - acc-pos: 100.0% - acc-neg: 24.4% - val-roc: 0.4665 - val-ap: 0.4652 (0.1s/epoch)
# Epoch  111/400: loss: 1.1007 - acc-pos: 100.0% - acc-neg: 24.0% - val-roc: 0.4649 - val-ap: 0.4643 (0.1s/epoch)
# Epoch  112/400: loss: 1.0981 - acc-pos: 100.0% - acc-neg: 23.6% - val-roc: 0.4648 - val-ap: 0.4641 (0.1s/epoch)
# Epoch  113/400: loss: 1.1016 - acc-pos: 100.0% - acc-neg: 23.5% - val-roc: 0.4641 - val-ap: 0.4640 (0.1s/epoch)
# Epoch  114/400: loss: 1.1005 - acc-pos: 100.0% - acc-neg: 23.5% - val-roc: 0.4638 - val-ap: 0.4643 (0.1s/epoch)
# Epoch  115/400: loss: 1.0976 - acc-pos: 100.0% - acc-neg: 23.4% - val-roc: 0.4603 - val-ap: 0.4628 (0.1s/epoch)
# Epoch  116/400: loss: 1.0987 - acc-pos: 100.0% - acc-neg: 23.3% - val-roc: 0.4582 - val-ap: 0.4620 (0.1s/epoch)
# Epoch  117/400: loss: 1.0967 - acc-pos: 100.0% - acc-neg: 23.2% - val-roc: 0.4540 - val-ap: 0.4601 (0.1s/epoch)
# Epoch  118/400: loss: 1.0931 - acc-pos: 100.0% - acc-neg: 23.5% - val-roc: 0.4551 - val-ap: 0.4609 (0.1s/epoch)
# Epoch  119/400: loss: 1.0917 - acc-pos: 100.0% - acc-neg: 23.7% - val-roc: 0.4568 - val-ap: 0.4620 (0.1s/epoch)
# Epoch  120/400: loss: 1.0957 - acc-pos: 100.0% - acc-neg: 23.8% - val-roc: 0.4599 - val-ap: 0.4638 (0.1s/epoch)
# Epoch  121/400: loss: 1.0948 - acc-pos: 100.0% - acc-neg: 24.0% - val-roc: 0.4641 - val-ap: 0.4662 (0.1s/epoch)
# Epoch  122/400: loss: 1.0947 - acc-pos: 100.0% - acc-neg: 24.1% - val-roc: 0.4672 - val-ap: 0.4675 (0.1s/epoch)
# Epoch  123/400: loss: 1.0937 - acc-pos: 100.0% - acc-neg: 24.1% - val-roc: 0.4678 - val-ap: 0.4675 (0.1s/epoch)
# Epoch  124/400: loss: 1.0927 - acc-pos: 100.0% - acc-neg: 24.2% - val-roc: 0.4685 - val-ap: 0.4680 (0.1s/epoch)
# Epoch  125/400: loss: 1.0911 - acc-pos: 100.0% - acc-neg: 24.2% - val-roc: 0.4700 - val-ap: 0.4689 (0.1s/epoch)
# Epoch  126/400: loss: 1.0898 - acc-pos: 100.0% - acc-neg: 24.7% - val-roc: 0.4715 - val-ap: 0.4701 (0.1s/epoch)
# Epoch  127/400: loss: 1.0889 - acc-pos: 100.0% - acc-neg: 24.8% - val-roc: 0.4706 - val-ap: 0.4697 (0.1s/epoch)
# Epoch  128/400: loss: 1.0840 - acc-pos: 100.0% - acc-neg: 24.9% - val-roc: 0.4691 - val-ap: 0.4691 (0.1s/epoch)
# Epoch  129/400: loss: 1.0820 - acc-pos: 100.0% - acc-neg: 24.9% - val-roc: 0.4662 - val-ap: 0.4676 (0.1s/epoch)
# Epoch  130/400: loss: 1.0932 - acc-pos: 100.0% - acc-neg: 25.0% - val-roc: 0.4637 - val-ap: 0.4662 (0.1s/epoch)
# Epoch  131/400: loss: 1.0822 - acc-pos: 100.0% - acc-neg: 24.9% - val-roc: 0.4610 - val-ap: 0.4646 (0.1s/epoch)
# Epoch  132/400: loss: 1.0857 - acc-pos: 100.0% - acc-neg: 24.7% - val-roc: 0.4598 - val-ap: 0.4636 (0.1s/epoch)
# Epoch  133/400: loss: 1.0836 - acc-pos: 100.0% - acc-neg: 24.4% - val-roc: 0.4594 - val-ap: 0.4631 (0.1s/epoch)
# Epoch  134/400: loss: 1.0907 - acc-pos: 100.0% - acc-neg: 24.9% - val-roc: 0.4613 - val-ap: 0.4641 (0.1s/epoch)
# Epoch  135/400: loss: 1.0806 - acc-pos: 100.0% - acc-neg: 25.0% - val-roc: 0.4633 - val-ap: 0.4655 (0.1s/epoch)
# Epoch  136/400: loss: 1.0800 - acc-pos: 100.0% - acc-neg: 25.0% - val-roc: 0.4652 - val-ap: 0.4671 (0.1s/epoch)
# Epoch  137/400: loss: 1.0759 - acc-pos: 100.0% - acc-neg: 25.0% - val-roc: 0.4666 - val-ap: 0.4680 (0.1s/epoch)
# Epoch  138/400: loss: 1.0771 - acc-pos: 100.0% - acc-neg: 25.1% - val-roc: 0.4685 - val-ap: 0.4692 (0.1s/epoch)
# Epoch  139/400: loss: 1.0745 - acc-pos: 100.0% - acc-neg: 25.0% - val-roc: 0.4710 - val-ap: 0.4707 (0.1s/epoch)
# Epoch  140/400: loss: 1.0845 - acc-pos: 100.0% - acc-neg: 24.9% - val-roc: 0.4709 - val-ap: 0.4711 (0.1s/epoch)
# Epoch  141/400: loss: 1.0802 - acc-pos: 100.0% - acc-neg: 24.6% - val-roc: 0.4692 - val-ap: 0.4706 (0.1s/epoch)
# Epoch  142/400: loss: 1.0726 - acc-pos: 100.0% - acc-neg: 24.7% - val-roc: 0.4672 - val-ap: 0.4698 (0.1s/epoch)
# Epoch  143/400: loss: 1.0744 - acc-pos: 100.0% - acc-neg: 24.8% - val-roc: 0.4678 - val-ap: 0.4701 (0.1s/epoch)
# Epoch  144/400: loss: 1.0651 - acc-pos: 100.0% - acc-neg: 25.2% - val-roc: 0.4686 - val-ap: 0.4701 (0.1s/epoch)
# Epoch  145/400: loss: 1.0798 - acc-pos: 100.0% - acc-neg: 25.5% - val-roc: 0.4702 - val-ap: 0.4709 (0.1s/epoch)
# Epoch  146/400: loss: 1.0831 - acc-pos: 100.0% - acc-neg: 25.6% - val-roc: 0.4685 - val-ap: 0.4700 (0.1s/epoch)
# Epoch  147/400: loss: 1.0718 - acc-pos: 100.0% - acc-neg: 25.3% - val-roc: 0.4670 - val-ap: 0.4694 (0.1s/epoch)
# Epoch  148/400: loss: 1.0661 - acc-pos: 100.0% - acc-neg: 25.3% - val-roc: 0.4640 - val-ap: 0.4677 (0.1s/epoch)
# Epoch  149/400: loss: 1.0733 - acc-pos: 100.0% - acc-neg: 25.4% - val-roc: 0.4614 - val-ap: 0.4663 (0.1s/epoch)
# Epoch  150/400: loss: 1.0691 - acc-pos: 100.0% - acc-neg: 25.5% - val-roc: 0.4608 - val-ap: 0.4660 (0.1s/epoch)
# Epoch  151/400: loss: 1.0634 - acc-pos: 100.0% - acc-neg: 25.6% - val-roc: 0.4618 - val-ap: 0.4663 (0.1s/epoch)
# Epoch  152/400: loss: 1.0743 - acc-pos: 100.0% - acc-neg: 26.0% - val-roc: 0.4628 - val-ap: 0.4664 (0.1s/epoch)
# Epoch  153/400: loss: 1.0644 - acc-pos: 100.0% - acc-neg: 26.1% - val-roc: 0.4636 - val-ap: 0.4667 (0.1s/epoch)
# Epoch  154/400: loss: 1.0678 - acc-pos: 100.0% - acc-neg: 26.3% - val-roc: 0.4642 - val-ap: 0.4669 (0.1s/epoch)
# Epoch  155/400: loss: 1.0699 - acc-pos: 100.0% - acc-neg: 26.1% - val-roc: 0.4612 - val-ap: 0.4657 (0.1s/epoch)
# Epoch  156/400: loss: 1.0633 - acc-pos: 100.0% - acc-neg: 25.9% - val-roc: 0.4573 - val-ap: 0.4639 (0.1s/epoch)
# Epoch  157/400: loss: 1.0625 - acc-pos: 100.0% - acc-neg: 25.5% - val-roc: 0.4536 - val-ap: 0.4623 (0.1s/epoch)
# Epoch  158/400: loss: 1.0587 - acc-pos: 100.0% - acc-neg: 25.1% - val-roc: 0.4528 - val-ap: 0.4618 (0.1s/epoch)
# Epoch  159/400: loss: 1.0633 - acc-pos: 100.0% - acc-neg: 25.2% - val-roc: 0.4541 - val-ap: 0.4623 (0.1s/epoch)
# Epoch  160/400: loss: 1.0604 - acc-pos: 100.0% - acc-neg: 25.5% - val-roc: 0.4576 - val-ap: 0.4643 (0.1s/epoch)
# Epoch  161/400: loss: 1.0562 - acc-pos: 100.0% - acc-neg: 25.9% - val-roc: 0.4627 - val-ap: 0.4672 (0.1s/epoch)
# Epoch  162/400: loss: 1.0624 - acc-pos: 100.0% - acc-neg: 26.2% - val-roc: 0.4685 - val-ap: 0.4706 (0.1s/epoch)
# Epoch  163/400: loss: 1.0561 - acc-pos: 100.0% - acc-neg: 26.6% - val-roc: 0.4742 - val-ap: 0.4741 (0.1s/epoch)
# Epoch  164/400: loss: 1.0588 - acc-pos: 100.0% - acc-neg: 26.5% - val-roc: 0.4769 - val-ap: 0.4751 (0.1s/epoch)
# Epoch  165/400: loss: 1.0559 - acc-pos: 100.0% - acc-neg: 26.4% - val-roc: 0.4770 - val-ap: 0.4748 (0.1s/epoch)
# Epoch  166/400: loss: 1.0589 - acc-pos: 100.0% - acc-neg: 26.0% - val-roc: 0.4748 - val-ap: 0.4734 (0.1s/epoch)
# Epoch  167/400: loss: 1.0593 - acc-pos: 100.0% - acc-neg: 25.8% - val-roc: 0.4703 - val-ap: 0.4711 (0.1s/epoch)
# Epoch  168/400: loss: 1.0516 - acc-pos: 100.0% - acc-neg: 25.9% - val-roc: 0.4668 - val-ap: 0.4694 (0.1s/epoch)
# Epoch  169/400: loss: 1.0569 - acc-pos: 100.0% - acc-neg: 26.1% - val-roc: 0.4645 - val-ap: 0.4678 (0.1s/epoch)
# Epoch  170/400: loss: 1.0578 - acc-pos: 100.0% - acc-neg: 26.5% - val-roc: 0.4672 - val-ap: 0.4693 (0.1s/epoch)
# Epoch  171/400: loss: 1.0512 - acc-pos: 100.0% - acc-neg: 26.9% - val-roc: 0.4695 - val-ap: 0.4703 (0.1s/epoch)
# Epoch  172/400: loss: 1.0557 - acc-pos: 100.0% - acc-neg: 27.0% - val-roc: 0.4714 - val-ap: 0.4715 (0.1s/epoch)
# Epoch  173/400: loss: 1.0504 - acc-pos: 100.0% - acc-neg: 27.2% - val-roc: 0.4736 - val-ap: 0.4726 (0.1s/epoch)
# Epoch  174/400: loss: 1.0492 - acc-pos: 100.0% - acc-neg: 27.2% - val-roc: 0.4737 - val-ap: 0.4727 (0.1s/epoch)
# Epoch  175/400: loss: 1.0497 - acc-pos: 100.0% - acc-neg: 27.1% - val-roc: 0.4715 - val-ap: 0.4718 (0.1s/epoch)
# Epoch  176/400: loss: 1.0593 - acc-pos: 100.0% - acc-neg: 26.9% - val-roc: 0.4656 - val-ap: 0.4692 (0.1s/epoch)
# Epoch  177/400: loss: 1.0450 - acc-pos: 100.0% - acc-neg: 26.5% - val-roc: 0.4609 - val-ap: 0.4671 (0.1s/epoch)
# Epoch  178/400: loss: 1.0470 - acc-pos: 100.0% - acc-neg: 26.5% - val-roc: 0.4583 - val-ap: 0.4658 (0.1s/epoch)
# Epoch  179/400: loss: 1.0461 - acc-pos: 100.0% - acc-neg: 26.4% - val-roc: 0.4580 - val-ap: 0.4655 (0.1s/epoch)
# Epoch  180/400: loss: 1.0418 - acc-pos: 100.0% - acc-neg: 26.7% - val-roc: 0.4613 - val-ap: 0.4671 (0.1s/epoch)
# Epoch  181/400: loss: 1.0491 - acc-pos: 100.0% - acc-neg: 27.4% - val-roc: 0.4671 - val-ap: 0.4700 (0.1s/epoch)
# Epoch  182/400: loss: 1.0409 - acc-pos: 100.0% - acc-neg: 27.6% - val-roc: 0.4710 - val-ap: 0.4717 (0.1s/epoch)
# Epoch  183/400: loss: 1.0432 - acc-pos: 100.0% - acc-neg: 27.7% - val-roc: 0.4734 - val-ap: 0.4727 (0.1s/epoch)
# Epoch  184/400: loss: 1.0442 - acc-pos: 100.0% - acc-neg: 27.7% - val-roc: 0.4732 - val-ap: 0.4722 (0.1s/epoch)
# Epoch  185/400: loss: 1.0403 - acc-pos: 100.0% - acc-neg: 27.5% - val-roc: 0.4730 - val-ap: 0.4721 (0.1s/epoch)
# Epoch  186/400: loss: 1.0421 - acc-pos: 100.0% - acc-neg: 27.6% - val-roc: 0.4727 - val-ap: 0.4724 (0.1s/epoch)
# Epoch  187/400: loss: 1.0378 - acc-pos: 100.0% - acc-neg: 27.2% - val-roc: 0.4716 - val-ap: 0.4720 (0.1s/epoch)
# Epoch  188/400: loss: 1.0384 - acc-pos: 100.0% - acc-neg: 27.1% - val-roc: 0.4713 - val-ap: 0.4724 (0.1s/epoch)
# Epoch  189/400: loss: 1.0374 - acc-pos: 100.0% - acc-neg: 26.9% - val-roc: 0.4713 - val-ap: 0.4731 (0.1s/epoch)
# Epoch  190/400: loss: 1.0461 - acc-pos: 100.0% - acc-neg: 27.1% - val-roc: 0.4716 - val-ap: 0.4737 (0.1s/epoch)
# Epoch  191/400: loss: 1.0339 - acc-pos: 100.0% - acc-neg: 27.1% - val-roc: 0.4722 - val-ap: 0.4740 (0.1s/epoch)
# Epoch  192/400: loss: 1.0380 - acc-pos: 100.0% - acc-neg: 27.3% - val-roc: 0.4736 - val-ap: 0.4749 (0.1s/epoch)
# Epoch  193/400: loss: 1.0344 - acc-pos: 100.0% - acc-neg: 27.4% - val-roc: 0.4746 - val-ap: 0.4754 (0.1s/epoch)
# Epoch  194/400: loss: 1.0360 - acc-pos: 100.0% - acc-neg: 27.6% - val-roc: 0.4751 - val-ap: 0.4754 (0.1s/epoch)
# Epoch  195/400: loss: 1.0357 - acc-pos: 100.0% - acc-neg: 27.6% - val-roc: 0.4744 - val-ap: 0.4750 (0.1s/epoch)
# Epoch  196/400: loss: 1.0317 - acc-pos: 100.0% - acc-neg: 27.4% - val-roc: 0.4712 - val-ap: 0.4731 (0.1s/epoch)
# Epoch  197/400: loss: 1.0324 - acc-pos: 100.0% - acc-neg: 27.6% - val-roc: 0.4695 - val-ap: 0.4726 (0.1s/epoch)
# Epoch  198/400: loss: 1.0305 - acc-pos: 100.0% - acc-neg: 27.6% - val-roc: 0.4693 - val-ap: 0.4726 (0.1s/epoch)
# Epoch  199/400: loss: 1.0329 - acc-pos: 100.0% - acc-neg: 28.1% - val-roc: 0.4702 - val-ap: 0.4733 (0.1s/epoch)
# Epoch  200/400: loss: 1.0331 - acc-pos: 100.0% - acc-neg: 28.3% - val-roc: 0.4706 - val-ap: 0.4736 (0.1s/epoch)
# Epoch  201/400: loss: 1.0262 - acc-pos: 100.0% - acc-neg: 28.3% - val-roc: 0.4695 - val-ap: 0.4732 (0.1s/epoch)
# Epoch  202/400: loss: 1.0276 - acc-pos: 100.0% - acc-neg: 28.4% - val-roc: 0.4702 - val-ap: 0.4739 (0.1s/epoch)
# Epoch  203/400: loss: 1.0268 - acc-pos: 100.0% - acc-neg: 28.7% - val-roc: 0.4720 - val-ap: 0.4751 (0.1s/epoch)
# Epoch  204/400: loss: 1.0295 - acc-pos: 100.0% - acc-neg: 28.6% - val-roc: 0.4729 - val-ap: 0.4757 (0.1s/epoch)
# Epoch  205/400: loss: 1.0287 - acc-pos: 100.0% - acc-neg: 28.4% - val-roc: 0.4728 - val-ap: 0.4754 (0.1s/epoch)
# Epoch  206/400: loss: 1.0235 - acc-pos: 100.0% - acc-neg: 28.0% - val-roc: 0.4693 - val-ap: 0.4736 (0.1s/epoch)
# Epoch  207/400: loss: 1.0261 - acc-pos: 100.0% - acc-neg: 27.8% - val-roc: 0.4668 - val-ap: 0.4720 (0.1s/epoch)
# Epoch  208/400: loss: 1.0257 - acc-pos: 100.0% - acc-neg: 28.0% - val-roc: 0.4638 - val-ap: 0.4698 (0.1s/epoch)
# Epoch  209/400: loss: 1.0282 - acc-pos: 100.0% - acc-neg: 28.2% - val-roc: 0.4643 - val-ap: 0.4696 (0.1s/epoch)
# Epoch  210/400: loss: 1.0188 - acc-pos: 100.0% - acc-neg: 28.6% - val-roc: 0.4663 - val-ap: 0.4705 (0.1s/epoch)
# Epoch  211/400: loss: 1.0214 - acc-pos: 100.0% - acc-neg: 29.1% - val-roc: 0.4700 - val-ap: 0.4724 (0.1s/epoch)
# Epoch  212/400: loss: 1.0209 - acc-pos: 100.0% - acc-neg: 29.5% - val-roc: 0.4743 - val-ap: 0.4750 (0.1s/epoch)
# Epoch  213/400: loss: 1.0278 - acc-pos: 100.0% - acc-neg: 29.8% - val-roc: 0.4790 - val-ap: 0.4780 (0.1s/epoch)
# Epoch  214/400: loss: 1.0218 - acc-pos: 100.0% - acc-neg: 29.9% - val-roc: 0.4822 - val-ap: 0.4799 (0.1s/epoch)
# Epoch  215/400: loss: 1.0178 - acc-pos: 100.0% - acc-neg: 29.7% - val-roc: 0.4832 - val-ap: 0.4807 (0.1s/epoch)
# Epoch  216/400: loss: 1.0237 - acc-pos: 100.0% - acc-neg: 29.3% - val-roc: 0.4805 - val-ap: 0.4794 (0.1s/epoch)
# Epoch  217/400: loss: 1.0197 - acc-pos: 100.0% - acc-neg: 28.5% - val-roc: 0.4761 - val-ap: 0.4765 (0.1s/epoch)
# Epoch  218/400: loss: 1.0178 - acc-pos: 100.0% - acc-neg: 27.8% - val-roc: 0.4705 - val-ap: 0.4733 (0.1s/epoch)
# Epoch  219/400: loss: 1.0179 - acc-pos: 100.0% - acc-neg: 27.5% - val-roc: 0.4693 - val-ap: 0.4723 (0.1s/epoch)
# Epoch  220/400: loss: 1.0187 - acc-pos: 100.0% - acc-neg: 27.8% - val-roc: 0.4715 - val-ap: 0.4731 (0.1s/epoch)
# Epoch  221/400: loss: 1.0189 - acc-pos: 100.0% - acc-neg: 28.3% - val-roc: 0.4743 - val-ap: 0.4744 (0.1s/epoch)
# Epoch  222/400: loss: 1.0176 - acc-pos: 100.0% - acc-neg: 28.8% - val-roc: 0.4750 - val-ap: 0.4748 (0.1s/epoch)
# Epoch  223/400: loss: 1.0215 - acc-pos: 100.0% - acc-neg: 29.3% - val-roc: 0.4766 - val-ap: 0.4761 (0.1s/epoch)
# Epoch  224/400: loss: 1.0185 - acc-pos: 100.0% - acc-neg: 29.5% - val-roc: 0.4777 - val-ap: 0.4774 (0.1s/epoch)
# Epoch  225/400: loss: 1.0098 - acc-pos: 100.0% - acc-neg: 29.5% - val-roc: 0.4771 - val-ap: 0.4776 (0.1s/epoch)
# Epoch  226/400: loss: 1.0102 - acc-pos: 100.0% - acc-neg: 29.3% - val-roc: 0.4743 - val-ap: 0.4769 (0.1s/epoch)
# Epoch  227/400: loss: 1.0111 - acc-pos: 100.0% - acc-neg: 29.2% - val-roc: 0.4718 - val-ap: 0.4761 (0.1s/epoch)
# Epoch  228/400: loss: 1.0149 - acc-pos: 100.0% - acc-neg: 29.2% - val-roc: 0.4710 - val-ap: 0.4758 (0.1s/epoch)
# Epoch  229/400: loss: 1.0102 - acc-pos: 100.0% - acc-neg: 29.3% - val-roc: 0.4725 - val-ap: 0.4768 (0.1s/epoch)
# Epoch  230/400: loss: 1.0075 - acc-pos: 100.0% - acc-neg: 29.1% - val-roc: 0.4736 - val-ap: 0.4772 (0.1s/epoch)
# Epoch  231/400: loss: 1.0030 - acc-pos: 100.0% - acc-neg: 29.5% - val-roc: 0.4764 - val-ap: 0.4780 (0.1s/epoch)
# Epoch  232/400: loss: 1.0067 - acc-pos: 100.0% - acc-neg: 29.5% - val-roc: 0.4764 - val-ap: 0.4774 (0.1s/epoch)
# Epoch  233/400: loss: 1.0116 - acc-pos: 100.0% - acc-neg: 29.6% - val-roc: 0.4747 - val-ap: 0.4762 (0.1s/epoch)
# Epoch  234/400: loss: 1.0026 - acc-pos: 100.0% - acc-neg: 29.4% - val-roc: 0.4731 - val-ap: 0.4751 (0.1s/epoch)
# Epoch  235/400: loss: 1.0069 - acc-pos: 100.0% - acc-neg: 29.6% - val-roc: 0.4736 - val-ap: 0.4756 (0.1s/epoch)
# Epoch  236/400: loss: 1.0111 - acc-pos: 100.0% - acc-neg: 29.8% - val-roc: 0.4738 - val-ap: 0.4759 (0.1s/epoch)
# Epoch  237/400: loss: 1.0052 - acc-pos: 100.0% - acc-neg: 30.0% - val-roc: 0.4751 - val-ap: 0.4769 (0.1s/epoch)
# Epoch  238/400: loss: 1.0018 - acc-pos: 100.0% - acc-neg: 30.3% - val-roc: 0.4757 - val-ap: 0.4776 (0.1s/epoch)
# Epoch  239/400: loss: 1.0015 - acc-pos: 100.0% - acc-neg: 30.7% - val-roc: 0.4759 - val-ap: 0.4779 (0.1s/epoch)
# Epoch  240/400: loss: 1.0026 - acc-pos: 100.0% - acc-neg: 30.9% - val-roc: 0.4748 - val-ap: 0.4775 (0.1s/epoch)
# Epoch  241/400: loss: 1.0009 - acc-pos: 100.0% - acc-neg: 31.0% - val-roc: 0.4745 - val-ap: 0.4776 (0.1s/epoch)
# Epoch  242/400: loss: 0.9978 - acc-pos: 100.0% - acc-neg: 31.0% - val-roc: 0.4733 - val-ap: 0.4772 (0.1s/epoch)
# Epoch  243/400: loss: 1.0040 - acc-pos: 100.0% - acc-neg: 30.7% - val-roc: 0.4698 - val-ap: 0.4754 (0.1s/epoch)
# Epoch  244/400: loss: 0.9971 - acc-pos: 100.0% - acc-neg: 30.2% - val-roc: 0.4650 - val-ap: 0.4730 (0.1s/epoch)
# Epoch  245/400: loss: 1.0004 - acc-pos: 100.0% - acc-neg: 29.9% - val-roc: 0.4609 - val-ap: 0.4712 (0.1s/epoch)
# Epoch  246/400: loss: 0.9994 - acc-pos: 100.0% - acc-neg: 29.4% - val-roc: 0.4566 - val-ap: 0.4690 (0.1s/epoch)
# Epoch  247/400: loss: 0.9975 - acc-pos: 100.0% - acc-neg: 29.8% - val-roc: 0.4583 - val-ap: 0.4698 (0.1s/epoch)
# Epoch  248/400: loss: 0.9938 - acc-pos: 100.0% - acc-neg: 30.2% - val-roc: 0.4621 - val-ap: 0.4723 (0.1s/epoch)
# Epoch  249/400: loss: 0.9950 - acc-pos: 100.0% - acc-neg: 30.9% - val-roc: 0.4678 - val-ap: 0.4758 (0.1s/epoch)
# Epoch  250/400: loss: 0.9967 - acc-pos: 100.0% - acc-neg: 30.9% - val-roc: 0.4706 - val-ap: 0.4776 (0.1s/epoch)
# Epoch  251/400: loss: 0.9983 - acc-pos: 100.0% - acc-neg: 31.1% - val-roc: 0.4733 - val-ap: 0.4796 (0.1s/epoch)
# Epoch  252/400: loss: 0.9961 - acc-pos: 100.0% - acc-neg: 31.2% - val-roc: 0.4737 - val-ap: 0.4800 (0.1s/epoch)
# Epoch  253/400: loss: 0.9969 - acc-pos: 100.0% - acc-neg: 31.2% - val-roc: 0.4731 - val-ap: 0.4796 (0.1s/epoch)
# Epoch  254/400: loss: 0.9944 - acc-pos: 100.0% - acc-neg: 31.0% - val-roc: 0.4705 - val-ap: 0.4784 (0.1s/epoch)
# Epoch  255/400: loss: 0.9885 - acc-pos: 100.0% - acc-neg: 30.6% - val-roc: 0.4670 - val-ap: 0.4766 (0.1s/epoch)
# Epoch  256/400: loss: 0.9914 - acc-pos: 100.0% - acc-neg: 30.5% - val-roc: 0.4651 - val-ap: 0.4756 (0.1s/epoch)
# Epoch  257/400: loss: 0.9895 - acc-pos: 100.0% - acc-neg: 31.0% - val-roc: 0.4664 - val-ap: 0.4767 (0.1s/epoch)
# Epoch  258/400: loss: 0.9872 - acc-pos: 100.0% - acc-neg: 31.1% - val-roc: 0.4675 - val-ap: 0.4776 (0.1s/epoch)
# Epoch  259/400: loss: 0.9859 - acc-pos: 100.0% - acc-neg: 31.2% - val-roc: 0.4697 - val-ap: 0.4790 (0.1s/epoch)
# Epoch  260/400: loss: 0.9901 - acc-pos: 100.0% - acc-neg: 31.5% - val-roc: 0.4741 - val-ap: 0.4814 (0.1s/epoch)
# Epoch  261/400: loss: 0.9909 - acc-pos: 100.0% - acc-neg: 31.7% - val-roc: 0.4762 - val-ap: 0.4829 (0.1s/epoch)
# Epoch  262/400: loss: 0.9863 - acc-pos: 100.0% - acc-neg: 31.7% - val-roc: 0.4770 - val-ap: 0.4836 (0.1s/epoch)
# Epoch  263/400: loss: 0.9831 - acc-pos: 100.0% - acc-neg: 31.4% - val-roc: 0.4749 - val-ap: 0.4829 (0.1s/epoch)
# Epoch  264/400: loss: 0.9874 - acc-pos: 100.0% - acc-neg: 31.4% - val-roc: 0.4740 - val-ap: 0.4823 (0.1s/epoch)
# Epoch  265/400: loss: 0.9873 - acc-pos: 100.0% - acc-neg: 31.4% - val-roc: 0.4736 - val-ap: 0.4818 (0.1s/epoch)
# Epoch  266/400: loss: 0.9845 - acc-pos: 100.0% - acc-neg: 31.0% - val-roc: 0.4714 - val-ap: 0.4804 (0.1s/epoch)
# Epoch  267/400: loss: 0.9780 - acc-pos: 100.0% - acc-neg: 31.0% - val-roc: 0.4719 - val-ap: 0.4807 (0.1s/epoch)
# Epoch  268/400: loss: 0.9840 - acc-pos: 100.0% - acc-neg: 31.7% - val-roc: 0.4759 - val-ap: 0.4825 (0.1s/epoch)
# Epoch  269/400: loss: 0.9811 - acc-pos: 100.0% - acc-neg: 32.1% - val-roc: 0.4800 - val-ap: 0.4847 (0.1s/epoch)
# Epoch  270/400: loss: 0.9768 - acc-pos: 100.0% - acc-neg: 32.3% - val-roc: 0.4828 - val-ap: 0.4863 (0.1s/epoch)
# Epoch  271/400: loss: 0.9806 - acc-pos: 100.0% - acc-neg: 32.6% - val-roc: 0.4861 - val-ap: 0.4883 (0.1s/epoch)
# Epoch  272/400: loss: 0.9814 - acc-pos: 100.0% - acc-neg: 32.8% - val-roc: 0.4871 - val-ap: 0.4890 (0.1s/epoch)
# Epoch  273/400: loss: 0.9787 - acc-pos: 100.0% - acc-neg: 32.7% - val-roc: 0.4874 - val-ap: 0.4897 (0.1s/epoch)
# Epoch  274/400: loss: 0.9753 - acc-pos: 100.0% - acc-neg: 32.5% - val-roc: 0.4851 - val-ap: 0.4885 (0.1s/epoch)
# Epoch  275/400: loss: 0.9754 - acc-pos: 100.0% - acc-neg: 31.9% - val-roc: 0.4809 - val-ap: 0.4865 (0.1s/epoch)
# Epoch  276/400: loss: 0.9765 - acc-pos: 100.0% - acc-neg: 31.5% - val-roc: 0.4750 - val-ap: 0.4834 (0.1s/epoch)
# Epoch  277/400: loss: 0.9748 - acc-pos: 100.0% - acc-neg: 31.3% - val-roc: 0.4709 - val-ap: 0.4807 (0.1s/epoch)
# Epoch  278/400: loss: 0.9763 - acc-pos: 100.0% - acc-neg: 31.5% - val-roc: 0.4689 - val-ap: 0.4793 (0.1s/epoch)
# Epoch  279/400: loss: 0.9710 - acc-pos: 100.0% - acc-neg: 32.1% - val-roc: 0.4704 - val-ap: 0.4796 (0.1s/epoch)
# Epoch  280/400: loss: 0.9698 - acc-pos: 100.0% - acc-neg: 32.4% - val-roc: 0.4713 - val-ap: 0.4799 (0.1s/epoch)
# Epoch  281/400: loss: 0.9743 - acc-pos: 100.0% - acc-neg: 32.7% - val-roc: 0.4728 - val-ap: 0.4803 (0.1s/epoch)
# Epoch  282/400: loss: 0.9706 - acc-pos: 100.0% - acc-neg: 32.9% - val-roc: 0.4728 - val-ap: 0.4800 (0.1s/epoch)
# Epoch  283/400: loss: 0.9775 - acc-pos: 100.0% - acc-neg: 33.1% - val-roc: 0.4720 - val-ap: 0.4796 (0.1s/epoch)
# Epoch  284/400: loss: 0.9737 - acc-pos: 100.0% - acc-neg: 33.0% - val-roc: 0.4714 - val-ap: 0.4789 (0.1s/epoch)
# Epoch  285/400: loss: 0.9703 - acc-pos: 100.0% - acc-neg: 32.9% - val-roc: 0.4706 - val-ap: 0.4783 (0.1s/epoch)
# Epoch  286/400: loss: 0.9699 - acc-pos: 100.0% - acc-neg: 32.7% - val-roc: 0.4696 - val-ap: 0.4777 (0.1s/epoch)
# Epoch  287/400: loss: 0.9624 - acc-pos: 100.0% - acc-neg: 32.8% - val-roc: 0.4700 - val-ap: 0.4781 (0.1s/epoch)
# Epoch  288/400: loss: 0.9718 - acc-pos: 100.0% - acc-neg: 33.1% - val-roc: 0.4716 - val-ap: 0.4790 (0.1s/epoch)
# Epoch  289/400: loss: 0.9707 - acc-pos: 100.0% - acc-neg: 33.4% - val-roc: 0.4730 - val-ap: 0.4798 (0.1s/epoch)
# Epoch  290/400: loss: 0.9659 - acc-pos: 100.0% - acc-neg: 33.4% - val-roc: 0.4741 - val-ap: 0.4806 (0.1s/epoch)
# Epoch  291/400: loss: 0.9645 - acc-pos: 100.0% - acc-neg: 33.3% - val-roc: 0.4740 - val-ap: 0.4805 (0.1s/epoch)
# Epoch  292/400: loss: 0.9651 - acc-pos: 100.0% - acc-neg: 33.4% - val-roc: 0.4730 - val-ap: 0.4796 (0.1s/epoch)
# Epoch  293/400: loss: 0.9624 - acc-pos: 100.0% - acc-neg: 33.6% - val-roc: 0.4741 - val-ap: 0.4801 (0.1s/epoch)
# Epoch  294/400: loss: 0.9656 - acc-pos: 100.0% - acc-neg: 33.6% - val-roc: 0.4753 - val-ap: 0.4811 (0.1s/epoch)
# Epoch  295/400: loss: 0.9614 - acc-pos: 100.0% - acc-neg: 33.5% - val-roc: 0.4733 - val-ap: 0.4800 (0.1s/epoch)
# Epoch  296/400: loss: 0.9670 - acc-pos: 100.0% - acc-neg: 33.2% - val-roc: 0.4708 - val-ap: 0.4790 (0.1s/epoch)
# Epoch  297/400: loss: 0.9631 - acc-pos: 100.0% - acc-neg: 33.2% - val-roc: 0.4715 - val-ap: 0.4799 (0.1s/epoch)
# Epoch  298/400: loss: 0.9605 - acc-pos: 100.0% - acc-neg: 33.5% - val-roc: 0.4745 - val-ap: 0.4821 (0.1s/epoch)
# Epoch  299/400: loss: 0.9610 - acc-pos: 100.0% - acc-neg: 34.1% - val-roc: 0.4779 - val-ap: 0.4846 (0.1s/epoch)
# Epoch  300/400: loss: 0.9654 - acc-pos: 100.0% - acc-neg: 34.8% - val-roc: 0.4827 - val-ap: 0.4875 (0.1s/epoch)
# Epoch  301/400: loss: 0.9596 - acc-pos: 100.0% - acc-neg: 34.9% - val-roc: 0.4847 - val-ap: 0.4886 (0.1s/epoch)
# Epoch  302/400: loss: 0.9608 - acc-pos: 100.0% - acc-neg: 34.5% - val-roc: 0.4837 - val-ap: 0.4880 (0.1s/epoch)
# Epoch  303/400: loss: 0.9623 - acc-pos: 100.0% - acc-neg: 33.8% - val-roc: 0.4795 - val-ap: 0.4855 (0.1s/epoch)
# Epoch  304/400: loss: 0.9558 - acc-pos: 100.0% - acc-neg: 33.2% - val-roc: 0.4746 - val-ap: 0.4829 (0.1s/epoch)
# Epoch  305/400: loss: 0.9553 - acc-pos: 100.0% - acc-neg: 33.1% - val-roc: 0.4713 - val-ap: 0.4809 (0.1s/epoch)
# Epoch  306/400: loss: 0.9618 - acc-pos: 100.0% - acc-neg: 33.1% - val-roc: 0.4710 - val-ap: 0.4808 (0.1s/epoch)
# Epoch  307/400: loss: 0.9571 - acc-pos: 100.0% - acc-neg: 33.7% - val-roc: 0.4747 - val-ap: 0.4829 (0.1s/epoch)
# Epoch  308/400: loss: 0.9585 - acc-pos: 100.0% - acc-neg: 34.1% - val-roc: 0.4793 - val-ap: 0.4852 (0.1s/epoch)
# Epoch  309/400: loss: 0.9578 - acc-pos: 100.0% - acc-neg: 34.3% - val-roc: 0.4810 - val-ap: 0.4860 (0.1s/epoch)
# Epoch  310/400: loss: 0.9570 - acc-pos: 100.0% - acc-neg: 34.3% - val-roc: 0.4802 - val-ap: 0.4852 (0.1s/epoch)
# Epoch  311/400: loss: 0.9527 - acc-pos: 100.0% - acc-neg: 34.5% - val-roc: 0.4799 - val-ap: 0.4851 (0.1s/epoch)
# Epoch  312/400: loss: 0.9547 - acc-pos: 100.0% - acc-neg: 34.5% - val-roc: 0.4783 - val-ap: 0.4840 (0.1s/epoch)
# Epoch  313/400: loss: 0.9554 - acc-pos: 100.0% - acc-neg: 34.8% - val-roc: 0.4778 - val-ap: 0.4840 (0.1s/epoch)
# Epoch  314/400: loss: 0.9571 - acc-pos: 100.0% - acc-neg: 35.1% - val-roc: 0.4783 - val-ap: 0.4843 (0.1s/epoch)
# Epoch  315/400: loss: 0.9477 - acc-pos: 100.0% - acc-neg: 35.3% - val-roc: 0.4770 - val-ap: 0.4840 (0.1s/epoch)
# Epoch  316/400: loss: 0.9585 - acc-pos: 100.0% - acc-neg: 35.3% - val-roc: 0.4729 - val-ap: 0.4814 (0.1s/epoch)
# Epoch  317/400: loss: 0.9466 - acc-pos: 100.0% - acc-neg: 34.9% - val-roc: 0.4692 - val-ap: 0.4797 (0.1s/epoch)
# Epoch  318/400: loss: 0.9506 - acc-pos: 100.0% - acc-neg: 34.8% - val-roc: 0.4665 - val-ap: 0.4780 (0.1s/epoch)
# Epoch  319/400: loss: 0.9566 - acc-pos: 100.0% - acc-neg: 34.7% - val-roc: 0.4653 - val-ap: 0.4771 (0.1s/epoch)
# Epoch  320/400: loss: 0.9504 - acc-pos: 100.0% - acc-neg: 34.8% - val-roc: 0.4650 - val-ap: 0.4767 (0.1s/epoch)
# Epoch  321/400: loss: 0.9506 - acc-pos: 100.0% - acc-neg: 35.4% - val-roc: 0.4684 - val-ap: 0.4784 (0.1s/epoch)
# Epoch  322/400: loss: 0.9538 - acc-pos: 100.0% - acc-neg: 35.8% - val-roc: 0.4713 - val-ap: 0.4802 (0.1s/epoch)
# Epoch  323/400: loss: 0.9454 - acc-pos: 100.0% - acc-neg: 35.6% - val-roc: 0.4723 - val-ap: 0.4807 (0.1s/epoch)
# Epoch  324/400: loss: 0.9419 - acc-pos: 100.0% - acc-neg: 35.3% - val-roc: 0.4725 - val-ap: 0.4807 (0.1s/epoch)
# Epoch  325/400: loss: 0.9468 - acc-pos: 100.0% - acc-neg: 35.1% - val-roc: 0.4724 - val-ap: 0.4804 (0.1s/epoch)
# Epoch  326/400: loss: 0.9417 - acc-pos: 100.0% - acc-neg: 35.0% - val-roc: 0.4728 - val-ap: 0.4808 (0.1s/epoch)
# Epoch  327/400: loss: 0.9415 - acc-pos: 100.0% - acc-neg: 35.0% - val-roc: 0.4738 - val-ap: 0.4815 (0.1s/epoch)
# Epoch  328/400: loss: 0.9463 - acc-pos: 100.0% - acc-neg: 35.3% - val-roc: 0.4752 - val-ap: 0.4825 (0.1s/epoch)
# Epoch  329/400: loss: 0.9433 - acc-pos: 100.0% - acc-neg: 35.6% - val-roc: 0.4760 - val-ap: 0.4832 (0.1s/epoch)
# Epoch  330/400: loss: 0.9460 - acc-pos: 100.0% - acc-neg: 36.1% - val-roc: 0.4776 - val-ap: 0.4845 (0.1s/epoch)
# Epoch  331/400: loss: 0.9372 - acc-pos: 100.0% - acc-neg: 36.2% - val-roc: 0.4786 - val-ap: 0.4853 (0.1s/epoch)
# Epoch  332/400: loss: 0.9415 - acc-pos: 100.0% - acc-neg: 36.2% - val-roc: 0.4799 - val-ap: 0.4865 (0.1s/epoch)
# Epoch  333/400: loss: 0.9386 - acc-pos: 100.0% - acc-neg: 36.3% - val-roc: 0.4810 - val-ap: 0.4875 (0.1s/epoch)
# Epoch  334/400: loss: 0.9407 - acc-pos: 100.0% - acc-neg: 36.2% - val-roc: 0.4798 - val-ap: 0.4872 (0.1s/epoch)
# Epoch  335/400: loss: 0.9385 - acc-pos: 100.0% - acc-neg: 35.7% - val-roc: 0.4772 - val-ap: 0.4861 (0.1s/epoch)
# Epoch  336/400: loss: 0.9396 - acc-pos: 100.0% - acc-neg: 35.3% - val-roc: 0.4734 - val-ap: 0.4842 (0.1s/epoch)
# Epoch  337/400: loss: 0.9351 - acc-pos: 100.0% - acc-neg: 35.0% - val-roc: 0.4710 - val-ap: 0.4830 (0.1s/epoch)
# Epoch  338/400: loss: 0.9378 - acc-pos: 100.0% - acc-neg: 35.6% - val-roc: 0.4725 - val-ap: 0.4836 (0.1s/epoch)
# Epoch  339/400: loss: 0.9368 - acc-pos: 100.0% - acc-neg: 35.9% - val-roc: 0.4747 - val-ap: 0.4843 (0.1s/epoch)
# Epoch  340/400: loss: 0.9380 - acc-pos: 100.0% - acc-neg: 36.5% - val-roc: 0.4789 - val-ap: 0.4860 (0.1s/epoch)
# Epoch  341/400: loss: 0.9296 - acc-pos: 100.0% - acc-neg: 36.8% - val-roc: 0.4817 - val-ap: 0.4873 (0.1s/epoch)
# Epoch  342/400: loss: 0.9318 - acc-pos: 100.0% - acc-neg: 37.2% - val-roc: 0.4837 - val-ap: 0.4882 (0.1s/epoch)
# Epoch  343/400: loss: 0.9309 - acc-pos: 100.0% - acc-neg: 37.4% - val-roc: 0.4850 - val-ap: 0.4888 (0.1s/epoch)
# Epoch  344/400: loss: 0.9284 - acc-pos: 100.0% - acc-neg: 37.4% - val-roc: 0.4860 - val-ap: 0.4897 (0.1s/epoch)
# Epoch  345/400: loss: 0.9372 - acc-pos: 100.0% - acc-neg: 37.4% - val-roc: 0.4862 - val-ap: 0.4902 (0.1s/epoch)
# Epoch  346/400: loss: 0.9344 - acc-pos: 100.0% - acc-neg: 37.3% - val-roc: 0.4837 - val-ap: 0.4891 (0.1s/epoch)
# Epoch  347/400: loss: 0.9314 - acc-pos: 100.0% - acc-neg: 36.9% - val-roc: 0.4806 - val-ap: 0.4877 (0.1s/epoch)
# Epoch  348/400: loss: 0.9333 - acc-pos: 100.0% - acc-neg: 36.8% - val-roc: 0.4778 - val-ap: 0.4867 (0.1s/epoch)
# Epoch  349/400: loss: 0.9301 - acc-pos: 100.0% - acc-neg: 36.4% - val-roc: 0.4737 - val-ap: 0.4847 (0.1s/epoch)
# Epoch  350/400: loss: 0.9336 - acc-pos: 100.0% - acc-neg: 36.5% - val-roc: 0.4742 - val-ap: 0.4852 (0.1s/epoch)
# Epoch  351/400: loss: 0.9315 - acc-pos: 100.0% - acc-neg: 36.6% - val-roc: 0.4748 - val-ap: 0.4854 (0.1s/epoch)
# Epoch  352/400: loss: 0.9266 - acc-pos: 100.0% - acc-neg: 37.1% - val-roc: 0.4783 - val-ap: 0.4874 (0.1s/epoch)
# Epoch  353/400: loss: 0.9257 - acc-pos: 100.0% - acc-neg: 37.5% - val-roc: 0.4816 - val-ap: 0.4891 (0.1s/epoch)
# Epoch  354/400: loss: 0.9285 - acc-pos: 100.0% - acc-neg: 37.7% - val-roc: 0.4826 - val-ap: 0.4897 (0.1s/epoch)
# Epoch  355/400: loss: 0.9281 - acc-pos: 100.0% - acc-neg: 37.8% - val-roc: 0.4826 - val-ap: 0.4893 (0.1s/epoch)
# Epoch  356/400: loss: 0.9261 - acc-pos: 100.0% - acc-neg: 38.0% - val-roc: 0.4830 - val-ap: 0.4891 (0.1s/epoch)
# Epoch  357/400: loss: 0.9252 - acc-pos: 100.0% - acc-neg: 38.1% - val-roc: 0.4817 - val-ap: 0.4881 (0.1s/epoch)
# Epoch  358/400: loss: 0.9216 - acc-pos: 100.0% - acc-neg: 38.2% - val-roc: 0.4809 - val-ap: 0.4880 (0.1s/epoch)
# Epoch  359/400: loss: 0.9235 - acc-pos: 100.0% - acc-neg: 38.2% - val-roc: 0.4805 - val-ap: 0.4877 (0.1s/epoch)
# Epoch  360/400: loss: 0.9223 - acc-pos: 100.0% - acc-neg: 38.0% - val-roc: 0.4803 - val-ap: 0.4875 (0.1s/epoch)
# Epoch  361/400: loss: 0.9260 - acc-pos: 100.0% - acc-neg: 37.5% - val-roc: 0.4775 - val-ap: 0.4861 (0.1s/epoch)
# Epoch  362/400: loss: 0.9211 - acc-pos: 100.0% - acc-neg: 36.5% - val-roc: 0.4720 - val-ap: 0.4834 (0.1s/epoch)
# Epoch  363/400: loss: 0.9217 - acc-pos: 100.0% - acc-neg: 36.0% - val-roc: 0.4685 - val-ap: 0.4818 (0.1s/epoch)
# Epoch  364/400: loss: 0.9301 - acc-pos: 100.0% - acc-neg: 36.5% - val-roc: 0.4693 - val-ap: 0.4825 (0.1s/epoch)
# Epoch  365/400: loss: 0.9215 - acc-pos: 100.0% - acc-neg: 37.3% - val-roc: 0.4749 - val-ap: 0.4856 (0.1s/epoch)
# Epoch  366/400: loss: 0.9167 - acc-pos: 100.0% - acc-neg: 37.8% - val-roc: 0.4791 - val-ap: 0.4879 (0.1s/epoch)
# Epoch  367/400: loss: 0.9222 - acc-pos: 100.0% - acc-neg: 38.2% - val-roc: 0.4803 - val-ap: 0.4886 (0.1s/epoch)
# Epoch  368/400: loss: 0.9214 - acc-pos: 100.0% - acc-neg: 38.2% - val-roc: 0.4797 - val-ap: 0.4885 (0.1s/epoch)
# Epoch  369/400: loss: 0.9193 - acc-pos: 100.0% - acc-neg: 38.2% - val-roc: 0.4771 - val-ap: 0.4873 (0.1s/epoch)
# Epoch  370/400: loss: 0.9161 - acc-pos: 100.0% - acc-neg: 38.0% - val-roc: 0.4745 - val-ap: 0.4862 (0.1s/epoch)
# Epoch  371/400: loss: 0.9158 - acc-pos: 100.0% - acc-neg: 37.8% - val-roc: 0.4714 - val-ap: 0.4846 (0.1s/epoch)
# Epoch  372/400: loss: 0.9159 - acc-pos: 100.0% - acc-neg: 37.6% - val-roc: 0.4676 - val-ap: 0.4823 (0.1s/epoch)
# Epoch  373/400: loss: 0.9154 - acc-pos: 100.0% - acc-neg: 37.4% - val-roc: 0.4636 - val-ap: 0.4798 (0.1s/epoch)
# Epoch  374/400: loss: 0.9155 - acc-pos: 100.0% - acc-neg: 37.8% - val-roc: 0.4648 - val-ap: 0.4802 (0.1s/epoch)
# Epoch  375/400: loss: 0.9208 - acc-pos: 100.0% - acc-neg: 38.6% - val-roc: 0.4699 - val-ap: 0.4826 (0.1s/epoch)
# Epoch  376/400: loss: 0.9167 - acc-pos: 100.0% - acc-neg: 39.3% - val-roc: 0.4749 - val-ap: 0.4856 (0.1s/epoch)
# Epoch  377/400: loss: 0.9152 - acc-pos: 100.0% - acc-neg: 39.5% - val-roc: 0.4772 - val-ap: 0.4866 (0.1s/epoch)
# Epoch  378/400: loss: 0.9146 - acc-pos: 100.0% - acc-neg: 39.6% - val-roc: 0.4803 - val-ap: 0.4883 (0.1s/epoch)
# Epoch  379/400: loss: 0.9106 - acc-pos: 100.0% - acc-neg: 39.4% - val-roc: 0.4814 - val-ap: 0.4892 (0.1s/epoch)
# Epoch  380/400: loss: 0.9141 - acc-pos: 100.0% - acc-neg: 39.0% - val-roc: 0.4812 - val-ap: 0.4894 (0.1s/epoch)
# Epoch  381/400: loss: 0.9106 - acc-pos: 100.0% - acc-neg: 38.5% - val-roc: 0.4803 - val-ap: 0.4895 (0.1s/epoch)
# Epoch  382/400: loss: 0.9121 - acc-pos: 100.0% - acc-neg: 37.7% - val-roc: 0.4778 - val-ap: 0.4881 (0.1s/epoch)
# Epoch  383/400: loss: 0.9116 - acc-pos: 100.0% - acc-neg: 37.5% - val-roc: 0.4761 - val-ap: 0.4870 (0.1s/epoch)
# Epoch  384/400: loss: 0.9083 - acc-pos: 100.0% - acc-neg: 38.1% - val-roc: 0.4763 - val-ap: 0.4869 (0.1s/epoch)
# Epoch  385/400: loss: 0.9084 - acc-pos: 100.0% - acc-neg: 38.6% - val-roc: 0.4770 - val-ap: 0.4873 (0.1s/epoch)
# Epoch  386/400: loss: 0.9147 - acc-pos: 100.0% - acc-neg: 39.0% - val-roc: 0.4770 - val-ap: 0.4874 (0.1s/epoch)
# Epoch  387/400: loss: 0.9125 - acc-pos: 100.0% - acc-neg: 39.4% - val-roc: 0.4766 - val-ap: 0.4872 (0.1s/epoch)
# Epoch  388/400: loss: 0.9069 - acc-pos: 100.0% - acc-neg: 39.5% - val-roc: 0.4759 - val-ap: 0.4868 (0.1s/epoch)
# Epoch  389/400: loss: 0.9034 - acc-pos: 100.0% - acc-neg: 39.7% - val-roc: 0.4752 - val-ap: 0.4862 (0.1s/epoch)
# Epoch  390/400: loss: 0.9054 - acc-pos: 100.0% - acc-neg: 40.0% - val-roc: 0.4760 - val-ap: 0.4861 (0.1s/epoch)
# Epoch  391/400: loss: 0.9027 - acc-pos: 100.0% - acc-neg: 40.2% - val-roc: 0.4752 - val-ap: 0.4854 (0.1s/epoch)
# Epoch  392/400: loss: 0.9045 - acc-pos: 100.0% - acc-neg: 40.3% - val-roc: 0.4747 - val-ap: 0.4851 (0.1s/epoch)
# Epoch  393/400: loss: 0.9012 - acc-pos: 100.0% - acc-neg: 40.5% - val-roc: 0.4748 - val-ap: 0.4849 (0.1s/epoch)
# Epoch  394/400: loss: 0.9051 - acc-pos: 100.0% - acc-neg: 40.9% - val-roc: 0.4769 - val-ap: 0.4865 (0.1s/epoch)
# Epoch  395/400: loss: 0.9038 - acc-pos: 100.0% - acc-neg: 40.9% - val-roc: 0.4772 - val-ap: 0.4866 (0.1s/epoch)
# Epoch  396/400: loss: 0.9016 - acc-pos: 100.0% - acc-neg: 41.0% - val-roc: 0.4783 - val-ap: 0.4873 (0.1s/epoch)
# Epoch  397/400: loss: 0.9042 - acc-pos: 100.0% - acc-neg: 40.8% - val-roc: 0.4775 - val-ap: 0.4872 (0.1s/epoch)
# Epoch  398/400: loss: 0.9013 - acc-pos: 100.0% - acc-neg: 40.3% - val-roc: 0.4750 - val-ap: 0.4857 (0.1s/epoch)
# Epoch  399/400: loss: 0.8994 - acc-pos: 100.0% - acc-neg: 40.2% - val-roc: 0.4743 - val-ap: 0.4854 (0.1s/epoch)
# Epoch  400/400: loss: 0.9042 - acc-pos: 100.0% - acc-neg: 40.4% - val-roc: 0.4756 - val-ap: 0.4862 (0.1s/epoch)
# Done!

# %% [markdown]
# ## 5. Evaluation
# Once we have our best model based on the performance on the *validation* set, we can do a final evaluation on a held-out set to get an idea of its predicting performance on new unseen data.
#
# **Note**: we subsample randomly the initial large graph on an already hard problem, so it's OK to obtain relatively low test performances.

# %%
test_roc, test_ap = test(data, model, data['test_edges'], data['test_edges_neg'])
print(f"Test ROC-AUC: {test_roc:.4f}")
print(f"Test AP: {test_ap:.4f}")

# Plot the ROC curve
fig = plot_roc_curve(data, model, data['test_edges'], data['test_edges_neg'])

# %% [markdown]
# Let's try to visualize the prediction of our network on subsets of the graph.
#
# You can play with `threshold`, the value above which we consider an edge to be predicted. By lowering it, we recover more edges (True Positives), at the risk of more False Positives.

# %%
N = 100  # number of node to keep for the visualization, keep it small for better visualization
threshold = 0.9  # threshold for edge prediction

def plot_pred_subgraph(graph, N, data, model, threshold=0.5):
    """Plot a subgraph with true and predicted edges."""
    # Ground-truth
    nodelist = np.random.permutation(graph.nodes())[:N]
    subgraph = graph.subgraph(nodelist).copy()
    subgraph.remove_edges_from(list(nx.selfloop_edges(subgraph)))  # remove self-loops for visualization
    subgraph.remove_nodes_from(list(nx.isolates(subgraph)))  # remove isolated nodes for visualization
    print(subgraph)
    pos = nx.spring_layout(subgraph, iterations=25)

    # Predict edges
    model.eval()
    pred_adj = model(data['x_train'], data['adj_train']).detach()
    pred_adj = torch.sigmoid(pred_adj) > threshold
    pred_edges = get_edge_index(pred_adj.detach().numpy())
    # Build a subgraph from the predicted edges
    subgraph_pred = nx.Graph()
    subgraph_pred.add_nodes_from(subgraph.nodes())
    nodes, subnodes = list(graph.nodes), set(subgraph.nodes())
    subgraph_pred.add_edges_from([(nodes[pred_edges[0][i]], nodes[pred_edges[1][i]]) for i in range(pred_edges.shape[1]) 
                                if nodes[pred_edges[0][i]] in subnodes and nodes[pred_edges[1][i]] in subnodes])
    subgraph_pred.remove_edges_from(list(nx.selfloop_edges(subgraph_pred)))  # remove self-loops for visualization
    print(f"{len(subgraph_pred.edges)} predicted edges")

    # Plot the subgraphs with GT and predicted edges
    fig, axs = plt.subplots(1, 2, figsize=(8, 4))
    fig.suptitle('Sub-graph of the yeast protein-protein interaction network')
    axs[0].set_title('Ground truth')
    axs[1].set_title('Prediction')
    for edge_set, color in [(train_edges, 'C0'), (valid_edges, 'C1'), (test_edges, 'C2')]:
        edgelist = subgraph.edges(np.array(graph.nodes())[edge_set[0]])
        nx.draw_networkx(subgraph, pos, edgelist=edgelist, ax=axs[0], with_labels=False, node_size=5, node_color='black', edge_color=color, width=1., alpha=0.5)
    nx.draw_networkx(subgraph_pred, pos, ax=axs[1], with_labels=False, node_size=5, node_color='black', edge_color='C3', width=1., alpha=0.5)
    axs[0].legend([Line2D([], [], color=c, linewidth=1., alpha=0.5) for c in ('C0', 'C1', 'C2')], ['train', 'validation', 'test'])
    axs[1].legend([Line2D([], [], color='C3', linewidth=1., alpha=0.5)], ['prediction']);
    return fig

fig = plot_pred_subgraph(graph, N, data, model, threshold=threshold)

# %% [markdown]
# ## 6. GraphSAGE
#
# Let's now try to implement GraphSAGE, which generalizes the architecture above to other types of neighbors aggregation.

# %% [markdown]
# ### 6.1. Network

# %% [markdown]
# Start by the graph convolutional layer below. It should take as argument an arbitrary aggregation method.
#
# The equation for the GraphSAGE layer is:
# $$
# \mathbf{h}_v^{(l+1)} = \sigma\left( \mathbf{W}_l \cdot \mathrm{CONCAT} \left[\mathbf{h}_v^{(l)}, \mathrm{AGG} \left(\left\{\mathbf{h}_u^{(l)}, \forall u\in N(v) \right\}\right) \right] \right),
# $$
# where $v$ index the node, $l$ the layer, $\mathbf{h}$ are the node embeddings, $\sigma$ is a non-linearity, $N(v)$ is the set of neighbor of node $v$, and $\mathbf{W}$ is the trainable weight matrix of the layer. $\mathrm{CONCAT}$ is the concatenation operation, while $\mathrm{AGG}$ is an arbitrary aggregation function.

# %%
class GraphSAGEConv(nn.Module):
    """GraphSAGE convolutional layer."""
    
    def __init__(self, in_features, out_features, aggregation, activation=None):
        """
        Initialize the GraphSAGE convolutional layer.
        
        Args:
            in_features (int): number of input node features.
            out_features (int): number of output node features.
            aggregation (nn.Module or callable): aggregation function to apply, as x_agg = aggegration(x, adj).
            activation (nn.Module or callable): activation function to apply. (optional)
        """
        super().__init__()
        ...  # TODO

    def forward(self, x, adj):
        """
        Perform graph convolution operation.

        Args:
            x (Tensor): Input node features of shape (num_nodes, in_features).
            adj (Tensor): Adjacency matrix of the graph, typically sparse, shape (num_nodes, num_nodes).

        Returns:
            Tensor: Output node features after graph convolution, shape (num_nodes, out_features).
        """
        ...  # TODO
        return ...

# %% [markdown]
# Now, implement some aggregation functions for the GraphSAGE layers:
# 1. `MeanAggregation`: average the neighbors, same as above,
# 2. `SumAggregation`: sum the neighbors,
# 3. `SqrtDegAggregation`: divide the sum of the neighbors by the square-root of the node degrees:  $$\mathrm{AGG} \left(\left\{\mathbf{h}_u^{(l)}, \forall u\in N(v) \right\}\right) = \sum_{u\in N(v)} \frac{\mathbf{h}_u^{(l)}}{\sqrt{\mathrm{deg}(v)}\sqrt{\mathrm{deg}(u)}},$$
# 4. `MaxPoolAggregation`: (optional) element-wise maximum over the neighbors. This is complex to code in pure PyTorch, so in this exercise we will implement it by simply looping over the nodes (even if it is slower).

# %%
# Note: all these aggregations take as input the node embedding x, adjacency matrix adj,
# and return the aggregated node embedding x_agg.

class MeanAggregation(nn.Module):
    """Aggregate node features by averaging over the neighborhood."""
    def __init__(self):
        super().__init__()

    def forward(self, x, adj):
        # Normalize the adjacency matrix
        degree = torch.sum(adj, dim=1, keepdim=True).clamp(min=1)
        adj = adj / degree

        # Aggregate neighborhood information using mean
        x_agg = torch.matmul(adj, x)
        return x_agg
    
class SumAggregation(nn.Module):
    """Aggregate node features by summing over the neighborhood."""
    def __init__(self):
        super().__init__()

    def forward(self, x, adj):
        ...  # TODO
        return ...

class SqrtDegAggregation(nn.Module):
    """Aggregate node features by summing over the neighborhood and normalizing by the degrees."""
    def __init__(self):
        super().__init__()

    def forward(self, x, adj):
        ...  # TODO
        return ...
    
class MaxPoolAggregation(nn.Module):
    """
    Aggregate node features by taking the maximum over the transformed neighborhood.

    Note: this is complicated to implement in pure PyTorch, so we will do a naive loop.
    """
    def __init__(self):
        super().__init__()

    def forward(self, x, adj):
        # Aggregate neighborhood information using max-pooling
        edge_index = torch.triu(adj).nonzero(as_tuple=False).t()  # edge indices (2, num_edges)
        x_agg = torch.zeros_like(x)
        # Loop on all nodes
        for i in range(x_agg.shape[0]):
            neighbors = x[edge_index[1, edge_index[0] == i]]
            if neighbors.shape[0] > 0:
                x_agg[i] = neighbors.max(dim=0)[0]
        return x_agg

# %% [markdown]
# Finally, build the whole graph network. Similarly as for the above GNN, it will have graphSAGE convolution layers, followed by a prediction head.

# %%
class GraphSAGE(nn.Module):
    """GraphSAGE Neural Network for edge prediction."""

    def __init__(self, num_features, conv_dims, aggregation, activation, dropout=0.):
        """
        Initialize the GraphSAGE model for edge prediction.

        Args:
            num_features (int): Number of input node features.
            conv_dims (list of int): Number of hidden features in the convolution layers.
            aggregation (nn.Module or callable): Aggregation function to apply.
            activation (nn.Module or callable): Activation function to apply.
            dropout (float): Dropout probability. (optional)
        """
        super().__init__()
        ...  # TODO

    def forward(self, x, adj):
        """
        Perform forward pass for edge prediction.

        Args:
            x (Tensor): Input node features of shape (num_nodes, num_features).
            adj (Tensor): Adjacency matrix of the graph, typically sparse, shape (num_nodes, num_nodes).

        Returns:
            Tensor: Predicted edge probabilities for each pair of nodes, shape (num_nodes, num_nodes).
        """
        ...  # TODO
        return ...

# %% [markdown]
# ### 6.2. Training and evaluation
# Similarly to above, let's train this model and evaluate its performance!

# %%
# Hyper-parameters (feel free to change these)
learning_rate = 1e-3
epochs = 400
conv_dims = [256, 128]
aggregation = SqrtDegAggregation()
activation = nn.LeakyReLU()
dropout = 0.1

# 1. Data
# We already loaded and prepared the data above

# 2. Model
modelSAGE = GraphSAGE(num_features=D_NODES, conv_dims=conv_dims, aggregation=aggregation, activation=activation, dropout=dropout)
#print(modelSAGE)

# 3. Initialize the loss function and optimizer
# We weight the samples to compensate for the class imbalance (there are very few edges compared to non-edges)
loss_fn = nn.BCEWithLogitsLoss(pos_weight=torch.tensor(pos_weight))
optimizer = torch.optim.Adam(modelSAGE.parameters(), lr=learning_rate)

history = {"epoch": 0, "loss": [], "acc-pos": [], "acc-neg": [], "val-roc": [], "val-ap": []}
# 4. Main training loop
history = train_loop(history, data, modelSAGE, loss_fn, optimizer, epochs)

fig, axs = plt.subplots(1, 4,  figsize=(16, 4))
axs[0].plot(history['loss'])
axs[0].set_title('Training loss')
axs[1].plot(history['acc-pos'], label='positive edges')
axs[1].plot(history['acc-neg'], label='negative edges')
axs[1].set_title('Training accuracy')
axs[1].legend()
axs[2].plot(history['val-roc'])
axs[2].set_title('Validation ROC-AUC')
axs[3].plot(history['val-ap'])
axs[3].set_title('Validation Average Precision');

# %%
test_roc, test_ap = test(data, modelSAGE, data['test_edges'], data['test_edges_neg'])
print(f"Test ROC-AUC: {test_roc:.4f}")
print(f"Test AP: {test_ap:.4f}")

# Plot the ROC curve
fig = plot_roc_curve(data, modelSAGE, data['test_edges'], data['test_edges_neg'])

# %%
N = 100  # number of node to keep for the visualization, keep it small for better visualization
threshold = 0.9  # threshold for edge prediction

fig = plot_pred_subgraph(graph, N, data, modelSAGE, threshold=threshold)
